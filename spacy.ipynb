# %%
import spacy
import pandas as pd

# %%
train_df = pd.read_csv('./Data/train.csv')

sentence = train_df['facts'][0]

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(sentence)

for token in doc:
    print(token.text, token.dep_, token.head.text)
# Out:
# On prep made
# June pobj On
# 27 nummod June
# , punct June
# 1962 nummod June
# , punct made
# Phil compound Amant
# St. compound Amant
# Amant nsubj made
# , punct Amant
# a det candidate
# candidate appos Amant
# for prep candidate
# public amod office
# office pobj for
# , punct Amant
# made ROOT made
# a det speech
# television compound speech
# speech dobj made
# in prep speech
# Baton compound Rouge
# Rouge pobj in
# , punct Rouge
# Louisiana appos Rouge
# . punct made
#   dep .
# During prep accused
# this det speech
# speech pobj During
# , punct accused
# St. compound Amant
# Amant nsubj accused
# accused ROOT accused
# his poss opponent
# political amod opponent
# opponent dobj accused
# of prep opponent
# being pcomp of
# a det Communist
# Communist attr being
# and cc of
# of conj of
# being auxpass involved
# involved pcomp of
# in prep involved
# criminal amod activities
# activities pobj in
# with prep involved
# the det head
# head pobj with
# of prep head
# the det Union
# local amod Union
# Teamsters compound Union
# Union pobj of
# . punct accused
#   dep .
# Finally advmod implicated
# , punct implicated
# St. compound Amant
# Amant nsubj implicated
# implicated ROOT implicated
# Herman compound Thompson
# Thompson dobj implicated
# , punct Thompson
# an det sheriff
# East compound Baton
# Baton compound Rouge
# Rouge compound sheriff
# deputy compound sheriff
# sheriff appos Thompson
# , punct implicated
# in prep implicated
# a det scheme
# scheme pobj in
# to aux move
# move acl scheme
# money dobj move
# between prep move
# the det Union
# Teamsters compound Union
# Union pobj between
# and cc Union
# St. compound Amant
# Amant poss opponent
# ’s case Amant
# political amod opponent
# opponent conj Union
# . punct implicated
#
#  dep .
# Thompson nsubj sued
# successfully advmod sued
# sued ROOT sued
# St. compound Amant
# Amant dobj sued
# for prep sued
# defamation pobj for
# . punct sued
#   dep .
# Louisiana poss Court
# ’s case Louisiana
# First compound Court
# Circuit compound Court
# Court nsubj reversed
# of prep Court
# Appeals pobj of
# reversed ROOT reversed
# , punct reversed
# holding advcl reversed
# that mark show
# Thompson nsubj show
# did aux show
# not neg show
# show ccomp holding
# St. compound Amant
# Amant nsubj acted
# acted ccomp reversed
# with prep acted
# “ punct with
# malice pobj with
# . punct acted
# ” punct acted
#   dep ”
# Thompson nsubj appealed
# then advmod appealed
# appealed ROOT appealed
# to prep appealed
# the det Court
# Supreme compound Court
# Court pobj to
# of prep Court
# Louisiana pobj of
# . punct appealed
#   dep .
# That det court
# court nsubj held
# held ROOT held
# that mark accused
# , punct accused
# although mark forfeit
# public amod figures
# figures nsubj forfeit
# forfeit advcl accused
# some dobj forfeit
# of prep some
# their poss protection
# First compound Amendment
# Amendment compound protection
# protection pobj of
# from prep protection
# defamation pobj from
# , punct accused
# St. compound Amant
# Amant nsubj accused
# accused ccomp held
# Thompson dobj accused
# of prep accused
# a det crime
# crime pobj of
# with prep crime
# utter amod disregard
# disregard pobj with
# of prep disregard
# whether mark were
# the det remarks
# remarks nsubj were
# were pcomp of
# true acomp were
# . punct held
#   dep .
# Finally advmod held
# , punct held
# that det court
# court nsubj held
# held ROOT held
# that mark protects
# the det Amendment
# First compound Amendment
# Amendment nsubj protects
# protects ccomp held
# uninhibited amod debate
# , punct debate
# robust amod debate
# debate dobj protects
# , punct debate
# rather advmod than
# than cc debate
# an det season
# open amod season
# season conj debate
# to aux shoot
# shoot relcl season
# down prt shoot
# the det name
# good amod name
# name dobj shoot
# of prep name
# anyone pobj of
# who nsubj happens
# happens relcl anyone
# to aux be
# be xcomp happens
# a det servant
# public amod servant
# servant attr be
# . punct held
#
#  dep .
