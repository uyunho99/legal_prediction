# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv("./Data/train.csv")
test_df = pd.read_csv("./Data/test.csv")

# %%
train_df
# Out:
#               ID                                   first_party  \
# 0     TRAIN_0000                             Phil A. St. Amant
# 1     TRAIN_0001                                Stephen Duncan
# 2     TRAIN_0002                             Billy Joe Magwood
# 3     TRAIN_0003                                    Linkletter
# 4     TRAIN_0004                            William Earl Fikes
# ...          ...                                           ...
# 2473  TRAIN_2473  HollyFrontier Cheyenne Refining, LLC, et al.
# 2474  TRAIN_2474           Grupo Mexicano de Desarrollo, S. A.
# 2475  TRAIN_2475                                       Peguero
# 2476  TRAIN_2476        Immigration and Naturalization Service
# 2477  TRAIN_2477                                       Markman
#
#                              second_party  \
# 0                      Herman A. Thompson
# 1                          Lawrence Owens
# 2          Tony Patterson, Warden, et al.
# 3                                  Walker
# 4                                 Alabama
# ...                                   ...
# 2473  Renewable Fuels Association, et al.
# 2474             Alliance Bond Fund, Inc.
# 2475                        United States
# 2476                              St. Cyr
# 2477           Westview Instruments, Inc.
#
#                                                   facts  first_party_winner
# 0     On June 27, 1962, Phil St. Amant, a candidate ...                   1
# 1     Ramon Nelson was riding his bike when he suffe...                   0
# 2     An Alabama state court convicted Billy Joe Mag...                   1
# 3     Victor Linkletter was convicted in state court...                   0
# 4     On April 24, 1953 in Selma, Alabama, an intrud...                   1
# ...                                                 ...                 ...
# 2473  Congress amended the Clean Air Act through the...                   1
# 2474  Alliance Bond Fund, Inc., an investment fund, ...                   1
# 2475  In 1992, the District Court sentenced Manuel D...                   0
# 2476  On March 8, 1996, Enrico St. Cyr, a lawful per...                   0
# 2477  Herbert Markman owns the patent to a system th...                   0
#
# [2478 rows x 5 columns]

# %%
train_df.sample(15)
# Out:
#               ID                                        first_party  \
# 1525  TRAIN_1525                                    Kevan Brumfield
# 1897  TRAIN_1897                                 Coeur Alaska, Inc.
# 677   TRAIN_0677                                               Koon
# 1056  TRAIN_1056                        Nitro-Lift Technologies LLC
# 1992  TRAIN_1992                                 Jerry Gunn, et al.
# 1151  TRAIN_1151                                Erik Lindsey Hughes
# 1699  TRAIN_1699                                              Davis
# 2294  TRAIN_2294                                   City of Lakewood
# 1624  TRAIN_1624            Equal Employment Opportunity Commission
# 1876  TRAIN_1876  R. K. Procunier, Director of the California De...
# 1571  TRAIN_1571                                               Horn
# 1515  TRAIN_1515                                     George W. Bush
# 1919  TRAIN_1919                                      United States
# 1393  TRAIN_1393                          Honda Motor Company, Ltd.
# 1592  TRAIN_1592                                            Pennell
#
#                                        second_party  \
# 1525                                      Burl Cain
# 1897  Southeast Alaska Conservation Council, et al.
# 677                                   United States
# 1056        Eddie Lee Howard and Shane D. Schneider
# 1992                                  Vernon Minton
# 1151                       United States of America
# 1699               Monroe County Board of Education
# 2294                    Plain Dealer Publishing Co.
# 1624               Abercrombie & Fitch Stores, Inc.
# 1876                                  Veron Atchley
# 1571                                          Banks
# 1515                                    Albert Gore
# 1919                                        Johnson
# 1393                                          Oberg
# 1592                               City of San Jose
#
#                                                   facts  first_party_winner
# 1525  In 1995, Kevan Brumfield was convicted of the ...                   1
# 1897  The United States Army Corps of Engineers (USA...                   1
# 677   Petitioners Stacey C. Koon and Laurence M. Pow...                   1
# 1056  Eddie Lee Howard and Shane D. Schneider worked...                   1
# 1992  In the early 1990s, Vernon Minton, a former se...                   1
# 1151  Erik Hughes pleaded guilty to drug and firearm...                   1
# 1699  Aurelia Davis sued the Monroe County Board of ...                   1
# 2294  Plain Dealer Publishing challenged the constit...                   0
# 1624  Abercrombie & Fitch Stores, Inc. (Abercrombie)...                   1
# 1876  In 1959, Veron Atchley was convicted of murder...                   1
# 1571  George Banks was convicted of 12 counts of fir...                   1
# 1515  Following the U.S. Supreme Court's decision in...                   1
# 1919  Roy Lee Johnson had been serving time in feder...                   1
# 1393  Karl Oberg was driving an all-terrain vehicle ...                   1
# 1592  The City of San Jose enacted a rent-control or...                   0

# %%
train_df['first_party'] = train_df['first_party'].str.lower()
train_df['second_party'] = train_df['second_party'].str.lower()
train_df['facts'] = train_df['facts'].str.lower()

test_df['first_party'] = test_df['first_party'].str.lower()
test_df['second_party'] = test_df['second_party'].str.lower()
test_df['facts'] = test_df['facts'].str.lower()

# %%
train_df
# Out:
#               ID                                   first_party  \
# 0     TRAIN_0000                             phil a. st. amant
# 1     TRAIN_0001                                stephen duncan
# 2     TRAIN_0002                             billy joe magwood
# 3     TRAIN_0003                                    linkletter
# 4     TRAIN_0004                            william earl fikes
# ...          ...                                           ...
# 2473  TRAIN_2473  hollyfrontier cheyenne refining, llc, et al.
# 2474  TRAIN_2474           grupo mexicano de desarrollo, s. a.
# 2475  TRAIN_2475                                       peguero
# 2476  TRAIN_2476        immigration and naturalization service
# 2477  TRAIN_2477                                       markman
#
#                              second_party  \
# 0                      herman a. thompson
# 1                          lawrence owens
# 2          tony patterson, warden, et al.
# 3                                  walker
# 4                                 alabama
# ...                                   ...
# 2473  renewable fuels association, et al.
# 2474             alliance bond fund, inc.
# 2475                        united states
# 2476                              st. cyr
# 2477           westview instruments, inc.
#
#                                                   facts  first_party_winner
# 0     on june 27, 1962, phil st. amant, a candidate ...                   1
# 1     ramon nelson was riding his bike when he suffe...                   0
# 2     an alabama state court convicted billy joe mag...                   1
# 3     victor linkletter was convicted in state court...                   0
# 4     on april 24, 1953 in selma, alabama, an intrud...                   1
# ...                                                 ...                 ...
# 2473  congress amended the clean air act through the...                   1
# 2474  alliance bond fund, inc., an investment fund, ...                   1
# 2475  in 1992, the district court sentenced manuel d...                   0
# 2476  on march 8, 1996, enrico st. cyr, a lawful per...                   0
# 2477  herbert markman owns the patent to a system th...                   0
#
# [2478 rows x 5 columns]

# %%
test_df
# Out:
#              ID                                        first_party  \
# 0     TEST_0000                                            salerno
# 1     TEST_0001             milberg weiss bershad hynes and lerach
# 2     TEST_0002  no. 07-582\t title: \t federal communications ...
# 3     TEST_0003                                    harold kaufman
# 4     TEST_0004                                             berger
# ...         ...                                                ...
# 1235  TEST_1235              haitian centers council, inc., et al.
# 1236  TEST_1236                                            whitman
# 1237  TEST_1237                linda a. matteo and john j. madigan
# 1238  TEST_1238      washington state apple advertising commission
# 1239  TEST_1239                                   theodore stovall
#
#                                            second_party  \
# 0                                         united states
# 1                                         lexecon, inc.
# 2                 fox television stations, inc., et al.
# 3                                         united states
# 4                                                hanlon
# ...                                                 ...
# 1235  chris sale, acting commissioner, immigration a...
# 1236               american trucking associations, inc.
# 1237                                    william g. barr
# 1238                                               hunt
# 1239                              wilfred denno, warden
#
#                                                   facts
# 0     the 1984 bail reform act allowed the federal c...
# 1     lexecon inc. was a defendant in a class action...
# 2     in 2002 and 2003, fox television stations broa...
# 3     during his trial for armed robbery of a federa...
# 4     in 1993, a magistrate judge issued a warrant a...
# ...                                                 ...
# 1235  according to executive order no. 12807 signed ...
# 1236  section 109(a) of the clean air act (caa) requ...
# 1237  linda matteo and john madigan created a plan f...
# 1238  in 1972, the north carolina board of agricultu...
# 1239  on august 23, 1961, dr. paul berheldt was stab...
#
# [1240 rows x 4 columns]

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("This is a test of the tokenize function.")
doc
# Out:
# 2023-06-27 00:39:12.478351: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-27 00:39:12.642452: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-27 00:39:13.278583: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bluesun/devel/lib:/opt/ros/noetic/lib:/opt/ros/noetic/lib/x86_64-linux-gnu:/home/dan/anaconda3/lib/:/home/dan/anaconda3/lib/python3.8/site-packages/tensorrt/:/home/dan/anaconda3/envs/tf/lib:/home/dan/anaconda3/envs/tf/lib/python3.8/site-packages/tensorrt/
# 2023-06-27 00:39:13.278639: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bluesun/devel/lib:/opt/ros/noetic/lib:/opt/ros/noetic/lib/x86_64-linux-gnu:/home/dan/anaconda3/lib/:/home/dan/anaconda3/lib/python3.8/site-packages/tensorrt/:/home/dan/anaconda3/envs/tf/lib:/home/dan/anaconda3/envs/tf/lib/python3.8/site-packages/tensorrt/
# 2023-06-27 00:39:13.278644: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-06-27 00:39:13.949506: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-06-27 00:39:13.949685: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bluesun/devel/lib:/opt/ros/noetic/lib:/opt/ros/noetic/lib/x86_64-linux-gnu:/home/dan/anaconda3/lib/:/home/dan/anaconda3/lib/python3.8/site-packages/tensorrt/:/home/dan/anaconda3/envs/tf/lib:/home/dan/anaconda3/envs/tf/lib/python3.8/site-packages/tensorrt/
# 2023-06-27 00:39:13.949726: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bluesun/devel/lib:/opt/ros/noetic/lib:/opt/ros/noetic/lib/x86_64-linux-gnu:/home/dan/anaconda3/lib/:/home/dan/anaconda3/lib/python3.8/site-packages/tensorrt/:/home/dan/anaconda3/envs/tf/lib:/home/dan/anaconda3/envs/tf/lib/python3.8/site-packages/tensorrt/
# 2023-06-27 00:39:13.949762: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bluesun/devel/lib:/opt/ros/noetic/lib:/opt/ros/noetic/lib/x86_64-linux-gnu:/home/dan/anaconda3/lib/:/home/dan/anaconda3/lib/python3.8/site-packages/tensorrt/:/home/dan/anaconda3/envs/tf/lib:/home/dan/anaconda3/envs/tf/lib/python3.8/site-packages/tensorrt/
# 2023-06-27 00:39:13.949796: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/bluesun/devel/lib:/opt/ros/noetic/lib:/opt/ros/noetic/lib/x86_64-linux-gnu:/home/dan/anaconda3/lib/:/home/dan/anaconda3/lib/python3.8/site-packages/tensorrt/:/home/dan/anaconda3/envs/tf/lib:/home/dan/anaconda3/envs/tf/lib/python3.8/site-packages/tensorrt/
# 2023-06-27 00:39:13.949817: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# This is a test of the tokenize function.

# %% [markdown]
# ### 이름을 인코딩 할 때의 문제
# 1. 이름의 first name만, last name만, first name + last name의 형태로 fact 내에 존재
# 2. 이름의 약자가 존재할 수 있음 (ex, 이하 '갑'이라 한다.)

# %%
idx = 1234
fact = train_df.loc[idx, 'facts'].lower()
first_party = train_df.loc[idx, 'first_party'].lower()
second_party = train_df.loc[idx, 'second_party'].lower()
print(fact)
print(first_party)
print(second_party)
# Out:
# carol anne bond was found guilty of trying to poison her husband's mistress, myrlinda haynes, with toxic chemicals at least 24 times over the course of several months. a grand jury in the eastern district of pennsylvania charged bond with two counts of possessing and using a chemical weapon, in violation of a criminal statute implementing the treaty obligations of the united states under the 1993 chemical weapons convention. the grand jury also charged bond with two counts of mail theft. bond's attorneys argue that the statute was intended to deal with rogue states and terrorists and that their client should have been prosecuted under state law instead. bond, a laboratory technician, stole the chemical potassium dichromate from the company where she worked. haynes was not injured. bond's husband had a child with haynes while married to bond. haynes had contacted police and postal authorities after finding the chemicals at her home. in september 2009, the u.s. court of appeals for the third circuit held that bond lacked standing to challenge the constitutionality of the statute on the basis of the tenth amendment.
#
# carol anne bond
# united states

# %%
from functools import reduce

def accumulate(iterable, gap=' '):
    it = iter(iterable)
    total = next(it)
    yield total
    for element in it:
        total += gap + element
        yield total

def cumulative_sum(lst):
    return list(accumulate(lst))

# %%
import string

string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

doc = nlp(fact)
for token in doc:
    print(token.text, token.dep_, token.head.text)
# Out:
# carol compound bond
# anne compound bond
# bond nsubjpass found
# was auxpass found
# found ROOT found
# guilty oprd found
# of prep guilty
# trying pcomp of
# to aux poison
# poison xcomp trying
# her poss husband
# husband poss mistress
# 's case husband
# mistress dobj poison
# , punct mistress
# myrlinda compound haynes
# haynes appos mistress
# , punct poison
# with prep poison
# toxic amod chemicals
# chemicals pobj with
# at advmod least
# least advmod 24
# 24 nummod times
# times npadvmod poison
# over prep poison
# the det course
# course pobj over
# of prep course
# several amod months
# months pobj of
# . punct found
# a det jury
# grand amod jury
# jury nsubj charged
# in prep jury
# the det district
# eastern amod district
# district pobj in
# of prep district
# pennsylvania pobj of
# charged ROOT charged
# bond dobj charged
# with prep charged
# two nummod counts
# counts pobj with
# of prep counts
# possessing pcomp of
# and cc possessing
# using conj possessing
# a det weapon
# chemical compound weapon
# weapon dobj using
# , punct charged
# in prep charged
# violation pobj in
# of prep violation
# a det statute
# criminal amod statute
# statute pobj of
# implementing acl statute
# the det obligations
# treaty compound obligations
# obligations dobj implementing
# of prep obligations
# the det states
# united compound states
# states pobj of
# under prep implementing
# the det convention
# 1993 nummod convention
# chemical compound weapons
# weapons compound convention
# convention pobj under
# . punct charged
# the det jury
# grand amod jury
# jury nsubj charged
# also advmod charged
# charged ROOT charged
# bond dobj charged
# with prep charged
# two nummod counts
# counts pobj with
# of prep counts
# mail compound theft
# theft pobj of
# . punct charged
# bond poss attorneys
# 's case bond
# attorneys nsubj argue
# argue ROOT argue
# that mark intended
# the det statute
# statute nsubjpass intended
# was auxpass intended
# intended ccomp argue
# to aux deal
# deal xcomp intended
# with prep deal
# rogue amod states
# states pobj with
# and cc states
# terrorists conj states
# and cc intended
# that mark prosecuted
# their poss client
# client nsubjpass prosecuted
# should aux prosecuted
# have aux prosecuted
# been auxpass prosecuted
# prosecuted conj intended
# under prep prosecuted
# state compound law
# law pobj under
# instead advmod prosecuted
# . punct argue
# bond nsubj stole
# , punct bond
# a det technician
# laboratory compound technician
# technician appos bond
# , punct bond
# stole ROOT stole
# the det dichromate
# chemical compound potassium
# potassium compound dichromate
# dichromate dobj stole
# from prep dichromate
# the det company
# company pobj from
# where advmod worked
# she nsubj worked
# worked relcl company
# . punct stole
# haynes nsubjpass injured
# was auxpass injured
# not neg injured
# injured ROOT injured
# . punct injured
# bond poss husband
# 's case bond
# husband nsubj had
# had ROOT had
# a det child
# child dobj had
# with prep had
# haynes pobj with
# while mark married
# married advcl had
# to prep married
# bond pobj to
# . punct had
# haynes nsubj contacted
# had aux contacted
# contacted ROOT contacted
# police dobj contacted
# and cc police
# postal amod authorities
# authorities conj police
# after prep contacted
# finding pcomp after
# the det chemicals
# chemicals dobj finding
# at prep finding
# her poss home
# home pobj at
# . punct contacted
# in prep held
# september pobj in
# 2009 nummod september
# , punct held
# the det court
# u.s compound court
# . compound court
# court nsubj held
# of prep court
# appeals pobj of
# for prep court
# the det circuit
# third amod circuit
# circuit pobj for
# held ROOT held
# that mark lacked
# bond nsubj lacked
# lacked ccomp held
# standing xcomp lacked
# to aux challenge
# challenge advcl standing
# the det constitutionality
# constitutionality dobj challenge
# of prep constitutionality
# the det statute
# statute pobj of
# on prep challenge
# the det basis
# basis pobj on
# of prep basis
# the det amendment
# tenth amod amendment
# amendment pobj of
# . punct held
#
#  dep .

# %%
# import re
# import difflib

# def get_fact_list_only_subj(fact):
#     doc = nlp(fact)
#     res = []
#     for token in doc:
#         if 'nsubj' in token.dep_:
#             res.append(token.text)
#     return res

# def get_name_cand(name, fact, cutoff=0.5):
#     name = re.sub(rf'[ .,{string.punctuation}]+', r' ', name.lower())
#     name_list = [n for n in name.split() if len(n) > 2]
#     print(f"name list: {name_list}")
#     res = []
#     fact_subj_list = get_fact_list_only_subj(fact)
#     for name_ in name_list:
#         cand = difflib.get_close_matches(name_, fact_subj_list, cutoff=cutoff)
#         print(f"cand for {name}: {cand}")
#         for c in cand:
#             res.append((c, len(re.findall(c, fact))))
#     return res

# %%
# re.findall(rf'\([\d\w]+\)', fact)

# %%
# re.sub(rf'')

# %%
def get_name_re(name, fact_token: spacy.tokens.doc.Doc, first=True):
    name = re.sub(rf'[ .,{string.punctuation}]+', r' ', name.lower())
    name_list = [n for n in name.split() if len(n) > 2]

    for n in name_list:
        changed_name = re.findall(rf"{n} ?\([a-z]+\)", fact_token.text)
        # print(f"changed name: {changed_name}")
        if changed_name:
            name_list.extend([re.sub(rf'({n}|[ {string.punctuation}])', '', cn) for cn in changed_name])

    # fact_subj = ' '.join([token.text for token in fact_token if 'NN' in token.tag_])
    # print(f"name list: {name_list}")
    # print(f"fact subj: {fact_subj}")
    # res = []
    # for name in name_list:
    #     res.append((name, len(re.findall(name, fact_subj))))
    # print(res)
    abbrev = "firstparty" if first else "secondparty"
    fact_subj = []
    for token in fact_token:
        if 'NN' in token.tag_ and token.text in name_list:
            fact_subj.append(abbrev)
        else:
            fact_subj.append(token.text)
    fact_subj = ' '.join(fact_subj)
    # fact_subj = re.sub(rf"({'|'.join(name_list)})", abbrev, fact)
    fact_subj = re.sub(rf"({abbrev} ?)+", f'{abbrev} ', fact_subj)
    return fact_subj

# %% [markdown]
# 이름 replace 시에 중간에 이름이 바뀌는 경우는 ()를 통해 표시하지 않는 한 포착 불가...

# %%
import re

def replace_name(first_party, second_party, fact_token: spacy.tokens.doc.Doc):
    first_party_name = re.sub(rf'[ .,{string.punctuation}]+', r' ', first_party.lower())
    second_party_name = re.sub(rf'[ .,{string.punctuation}]+', r' ', second_party.lower())
    fp_name_list = [n for n in first_party_name.split() if len(n) > 2]
    sp_name_list = [n for n in second_party_name.split() if len(n) > 2]

    fp_name_list_added = fp_name_list.copy()
    sp_name_list_added = sp_name_list.copy()

    for n in fp_name_list:
        changed_name = re.findall(rf"{n} ?\([a-z]+\)", fact_token.text)
        if changed_name:
            fp_name_list_added.extend([re.sub(rf'({n}|[ {string.punctuation}])', '', cn) for cn in changed_name])
    
    for n in sp_name_list:
        changed_name = re.findall(rf"{n} ?\([a-z]+\)", fact_token.text)
        if changed_name:
            sp_name_list_added.extend([re.sub(rf'({n}|[ {string.punctuation}])', '', cn) for cn in changed_name])

    # for name_list in [fp_name_list, sp_name_list]:
    #     for n in name_list:
    #         changed_name = re.findall(rf"{n} ?\([a-z]+\)", fact_token.text)
    #         if changed_name:
    #             name_list.extend([re.sub(rf'({n}|[ {string.punctuation}])', '', cn) for cn in changed_name])
    
    # print(f"fp name list: {fp_name_list}")
    # print(f"sp name list: {sp_name_list}")

    fact_subj = []
    for token in fact_token:
        if 'NN' in token.tag_:
            if token.text in fp_name_list_added:
                fact_subj.append('firstparty')
            elif token.text in sp_name_list_added:
                fact_subj.append('secondparty')
            else:
                fact_subj.append(token.text)
        else:
            fact_subj.append(token.text)
    
    fact_subj = ' '.join(fact_subj)
    fact_subj = re.sub(rf"(firstparty ?)+", f'firstparty ', fact_subj)
    fact_subj = re.sub(rf"(secondparty ?)+", f'secondparty ', fact_subj)
    return fact_subj

# %%
x = "United States of America (USA)"
y = "South Korea, m.g., SK, is "

# %%
# def get_name_list(name):
#     name_cleaned = re.sub(rf'[ .,{string.punctuation}]+', r' ', name.lower())
#     name_list = [n for n in name_cleaned.split() if len(n) > 2]

#     # for n in name_list:
#     #     changed_name = re.findall(rf"{n} ?\([a-z]+\)", fact_token.text)
#     #     if changed_name:
#     #         name_list.extend([re.sub(rf'({n}|[ {string.punctuation}])', '', cn) for cn in changed_name])

#     return name_list


# def replace_name(fp_list, sp_list, fact_token: spacy.tokens.doc.Doc):
#     fact_subj = []
#     for token in fact_token:
#         if 'NN' in token.tag_:
#             if token.text in fp_list:
#                 fact_subj.append('firstparty')
#             elif token.text in sp_list:
#                 fact_subj.append('secondparty')
#             else:
#                 fact_subj.append(token.text)
#         else:
#             fact_subj.append(token.text)
    
#     fact_subj = ' '.join(fact_subj)
#     fact_subj = re.sub(rf"(firstparty ?)+", f'firstparty ', fact_subj)
#     fact_subj = re.sub(rf"(secondparty ?)+", f'secondparty ', fact_subj)
#     return fact_subj

# def get_additional_name_list(fact_cleaned):
#     name_list = re.findall(rf"(firstparty|secondparty) ?\([a-z.,']+\)", fact_cleaned)
#     if name_list:
#         name_list = [re.sub(rf" ?\([a-z.,']+\)", "", name) for name in name_list]

# %%
from pandarallel import pandarallel

pandarallel.initialize(progress_bar=True, nb_workers=8)

# train_df['facts_token'] = train_df['facts'].parallel_apply(nlp)
train_df['new_facts'] = train_df.parallel_apply(lambda x: replace_name(x['first_party'], x['second_party'], nlp(x['facts'])), axis=1)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=310), Label(value='0 / 310'))), HB…

# %%
print(train_df['new_facts'][0])
print(train_df['facts'][0])
# Out:
# on june 27 , 1962 , firstparty , a candidate for public office , made a television speech in baton rouge , louisiana .   during this speech , firstparty accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union .   finally , firstparty implicated secondparty , an east baton rouge deputy sheriff , in a scheme to move money between the teamsters union and firstparty ’s political opponent .
#  secondparty successfully sued firstparty for defamation .   louisiana ’s first circuit court of appeals reversed , holding that secondparty did not show firstparty acted with “ malice . ”   secondparty then appealed to the supreme court of louisiana .   that court held that , although public figures forfeit some of their first amendment protection from defamation , firstparty accused secondparty of a crime with utter disregard of whether the remarks were true .   finally , that court held that the first amendment protects uninhibited , robust debate , rather than an open season to shoot down the good name of anyone who happens to be a public servant .
#
# on june 27, 1962, phil st. amant, a candidate for public office, made a television speech in baton rouge, louisiana.  during this speech, st. amant accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union.  finally, st. amant implicated herman thompson, an east baton rouge deputy sheriff, in a scheme to move money between the teamsters union and st. amant’s political opponent.
# thompson successfully sued st. amant for defamation.  louisiana’s first circuit court of appeals reversed, holding that thompson did not show st. amant acted with “malice.”  thompson then appealed to the supreme court of louisiana.  that court held that, although public figures forfeit some of their first amendment protection from defamation, st. amant accused thompson of a crime with utter disregard of whether the remarks were true.  finally, that court held that the first amendment protects uninhibited, robust debate, rather than an open season to shoot down the good name of anyone who happens to be a public servant.

# %%
test_df['new_facts'] = test_df.parallel_apply(lambda x: replace_name(x['first_party'], x['second_party'], nlp(x['facts'])), axis=1)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=155), Label(value='0 / 155'))), HB…

# %%
test_df
# Out:
#              ID                                        first_party  \
# 0     TEST_0000                                            salerno
# 1     TEST_0001             milberg weiss bershad hynes and lerach
# 2     TEST_0002  no. 07-582\t title: \t federal communications ...
# 3     TEST_0003                                    harold kaufman
# 4     TEST_0004                                             berger
# ...         ...                                                ...
# 1235  TEST_1235              haitian centers council, inc., et al.
# 1236  TEST_1236                                            whitman
# 1237  TEST_1237                linda a. matteo and john j. madigan
# 1238  TEST_1238      washington state apple advertising commission
# 1239  TEST_1239                                   theodore stovall
#
#                                            second_party  \
# 0                                         united states
# 1                                         lexecon, inc.
# 2                 fox television stations, inc., et al.
# 3                                         united states
# 4                                                hanlon
# ...                                                 ...
# 1235  chris sale, acting commissioner, immigration a...
# 1236               american trucking associations, inc.
# 1237                                    william g. barr
# 1238                                               hunt
# 1239                              wilfred denno, warden
#
#                                                   facts  \
# 0     the 1984 bail reform act allowed the federal c...
# 1     lexecon inc. was a defendant in a class action...
# 2     in 2002 and 2003, fox television stations broa...
# 3     during his trial for armed robbery of a federa...
# 4     in 1993, a magistrate judge issued a warrant a...
# ...                                                 ...
# 1235  according to executive order no. 12807 signed ...
# 1236  section 109(a) of the clean air act (caa) requ...
# 1237  linda matteo and john madigan created a plan f...
# 1238  in 1972, the north carolina board of agricultu...
# 1239  on august 23, 1961, dr. paul berheldt was stab...
#
#                                               new_facts
# 0     the 1984 bail reform act allowed the federal c...
# 1     secondparty was a defendant in a class action ...
# 2     in 2002 and 2003 , fox secondparty broadcast t...
# 3     during his trial for armed robbery of a federa...
# 4     in 1993 , a magistrate judge issued a warrant ...
# ...                                                 ...
# 1235  according to executive order no firstparty 128...
# 1236  section 109(a ) of the clean air act ( caa ) r...
# 1237  firstparty and firstparty created a plan for u...
# 1238  in 1972 , the north carolina board of agricult...
# 1239  on august 23 , 1961 , dr . paul berheldt was s...
#
# [1240 rows x 5 columns]

# %%
idx = 912
first_party = train_df.loc[idx, 'first_party'].lower()
second_party = train_df.loc[idx, 'second_party'].lower()
fact = train_df.loc[idx, 'facts'].lower()
fact_token = nlp(fact)
print(fact)
print(first_party)
print(second_party)
# Out:
# on march 12, 2003, steven levin was scheduled to undergo cataract surgery performed by lieutenant commander frank bishop, m.d., a united states navy surgeon in guam. levin previously gave his written consent to the procedure but claims that he attempted to orally withdraw it prior to the surgery. he suffered complications from the surgery and faces continuing treatment with unclear likelihood of success. levin sued dr. bishop for battery and negligent medical malpractice. the united states substituted itself for dr. bishop and filed a motion for summary judgment. the district court granted summary judgment for the negligent medical malpractice claim, not the battery claim. the united states then filed for dismissal of the battery claim and alleged that the federal tort claims act preserved sovereign immunity against battery claims. the district court dismissed the claim. the united states court of appeals for the ninth circuit affirmed.
#
# steven a. levin
# united states, et al.

# %%
print(replace_name(first_party, second_party, fact_token))
print(fact)
# Out:
# on march 12 , 2003 , firstparty was scheduled to undergo cataract surgery performed by lieutenant commander frank bishop , m.d firstparty , a secondparty navy surgeon in guam . firstparty previously gave his written consent to the procedure but claims that he attempted to orally withdraw it prior to the surgery . he suffered complications from the surgery and faces continuing treatment with unclear likelihood of success . firstparty sued dr firstparty bishop for battery and negligent medical malpractice . the secondparty substituted itself for dr firstparty bishop and filed a motion for summary judgment . the district court granted summary judgment for the negligent medical malpractice claim , not the battery claim . the secondparty then filed for dismissal of the battery claim and alleged that the federal tort claims act preserved sovereign immunity against battery claims . the district court dismissed the claim . the secondparty court of appeals for the ninth circuit affirmed .
#
# on march 12, 2003, steven levin was scheduled to undergo cataract surgery performed by lieutenant commander frank bishop, m.d., a united states navy surgeon in guam. levin previously gave his written consent to the procedure but claims that he attempted to orally withdraw it prior to the surgery. he suffered complications from the surgery and faces continuing treatment with unclear likelihood of success. levin sued dr. bishop for battery and negligent medical malpractice. the united states substituted itself for dr. bishop and filed a motion for summary judgment. the district court granted summary judgment for the negligent medical malpractice claim, not the battery claim. the united states then filed for dismissal of the battery claim and alleged that the federal tort claims act preserved sovereign immunity against battery claims. the district court dismissed the claim. the united states court of appeals for the ninth circuit affirmed.

# %%
import prettytable

table = prettytable.PrettyTable()
table.field_names = ['Token', 'Lemma', 'POS', 'Tag', 'Dep', "HEAD"]

for token in fact_token:
    table.add_row([token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.head.text])

print(table)
# Out:
# +----------------+---------------+-------+-------+-----------+----------------+
# |     Token      |     Lemma     |  POS  |  Tag  |    Dep    |      HEAD      |
# +----------------+---------------+-------+-------+-----------+----------------+
# |      the       |      the      |  DET  |   DT  |    det    |   promotion    |
# |      beef      |      beef     |  NOUN |   NN  |  compound |   promotion    |
# |   promotion    |   promotion   |  NOUN |   NN  |    nmod   |   producers    |
# |      and       |      and      | CCONJ |   CC  |     cc    |   promotion    |
# |    research    |    research   |  NOUN |   NN  |  compound |      act       |
# |      act       |      act      |  NOUN |   NN  |    conj   |   promotion    |
# |       (        |       (       | PUNCT | -LRB- |   punct   |   promotion    |
# |      1985      |      1985     |  NUM  |   CD  |   appos   |   promotion    |
# |       )        |       )       | PUNCT | -RRB- |   punct   |   promotion    |
# |    required    |    require    |  VERB |  VBN  |    amod   |   producers    |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |   producers    |
# |   producers    |    producer   |  NOUN |  NNS  |   nsubj   |      pay       |
# |       to       |       to      |  PART |   TO  |    aux    |      pay       |
# |      pay       |      pay      |  VERB |   VB  |    ROOT   |      pay       |
# |       a        |       a       |  DET  |   DT  |    det    |      fee       |
# |      fee       |      fee      |  NOUN |   NN  |    dobj   |      pay       |
# |      for       |      for      |  ADP  |   IN  |    prep   |      fee       |
# |    generic     |    generic    |  ADJ  |   JJ  |    amod   |      beef      |
# |      beef      |      beef     |  NOUN |   NN  |  compound | advertisements |
# | advertisements | advertisement |  NOUN |  NNS  |    pobj   |      for       |
# |      done      |       do      |  VERB |  VBN  |    acl    | advertisements |
# |       on       |       on      |  ADP  |   IN  |    prep   |      done      |
# |     behalf     |     behalf    |  NOUN |   NN  |    pobj   |       on       |
# |       of       |       of      |  ADP  |   IN  |    prep   |     behalf     |
# |      the       |      the      |  DET  |   DT  |    det    |    industry    |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |    industry    |
# |    industry    |    industry   |  NOUN |   NN  |    pobj   |       of       |
# |       .        |       .       | PUNCT |   .   |   punct   |      pay       |
# |      some      |      some     |  DET  |   DT  |    det    |   producers    |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |   producers    |
# |   producers    |    producer   |  NOUN |  NNS  |   nsubj   |   disagreed    |
# |   disagreed    |    disagree   |  VERB |  VBD  |    ROOT   |   disagreed    |
# |      with      |      with     |  ADP  |   IN  |    prep   |   disagreed    |
# |      the       |      the      |  DET  |   DT  |    det    | advertisements |
# | advertisements | advertisement |  NOUN |  NNS  |    pobj   |      with      |
# |       .        |       .       | PUNCT |   .   |   punct   |   disagreed    |
# |      the       |      the      |  DET  |   DT  |    det    |  association   |
# |   livestock    |   livestock   |  NOUN |   NN  |  compound |   marketing    |
# |   marketing    |   marketing   |  NOUN |   NN  |  compound |  association   |
# |  association   |  association  |  NOUN |   NN  |   nsubj   |      sued      |
# |      sued      |      sue      |  VERB |  VBD  |    ROOT   |      sued      |
# |      the       |      the      |  DET  |   DT  |    det    |   department   |
# |   department   |   department  |  NOUN |   NN  |    dobj   |      sued      |
# |       of       |       of      |  ADP  |   IN  |    prep   |   department   |
# |  agriculture   |  agriculture  | PROPN |  NNP  |    pobj   |       of       |
# |       (        |       (       | PUNCT | -LRB- |   punct   |  agriculture   |
# |      usda      |      usda     |  NOUN |  NNS  |   appos   |  agriculture   |
# |       )        |       )       | PUNCT | -RRB- |   punct   |  agriculture   |
# |       in       |       in      |  ADP  |   IN  |    prep   |      sued      |
# |    federal     |    federal    |  ADJ  |   JJ  |    amod   |     court      |
# |    district    |    district   |  NOUN |   NN  |  compound |     court      |
# |     court      |     court     |  NOUN |   NN  |    pobj   |       in       |
# |      and       |      and      | CCONJ |   CC  |     cc    |      sued      |
# |    alleged     |     allege    |  VERB |  VBD  |    conj   |      sued      |
# |       a        |       a       |  DET  |   DT  |    det    |      fee       |
# |   government   |   government  |  NOUN |   NN  |  npadvmod |    required    |
# |       -        |       -       | PUNCT |  HYPH |   punct   |    required    |
# |    required    |    require    |  VERB |  VBN  |    amod   |      fee       |
# |      fee       |      fee      |  NOUN |   NN  |    dobj   |    alleged     |
# |      for       |      for      |  ADP  |   IN  |    prep   |      fee       |
# |  advertising   |  advertising  |  NOUN |   NN  |    pobj   |      for       |
# |      with      |      with     |  ADP  |   IN  |    prep   |   disagreed    |
# |     which      |     which     |  PRON |  WDT  |    pobj   |      with      |
# |      some      |      some     |  DET  |   DT  |    det    |   producers    |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |   producers    |
# |   producers    |    producer   |  NOUN |  NNS  |   nsubj   |   disagreed    |
# |   disagreed    |    disagree   |  VERB |  VBD  |   relcl   |      fee       |
# |    violated    |    violate    |  VERB |  VBD  |   ccomp   |    alleged     |
# |     their      |     their     |  PRON |  PRP$ |    poss   |   amendment    |
# |     first      |     first     |  ADJ  |   JJ  |    amod   |   amendment    |
# |   amendment    |   amendment   |  NOUN |   NN  |    dobj   |    violated    |
# |     right      |     right     |  NOUN |   NN  |    dobj   |    violated    |
# |       to       |       to      |  ADP  |   IN  |    prep   |     right      |
# |      free      |      free     |  ADJ  |   JJ  |    amod   |     speech     |
# |     speech     |     speech    |  NOUN |   NN  |    pobj   |       to       |
# |       .        |       .       | PUNCT |   .   |   punct   |      sued      |
# |      the       |      the      |  DET  |   DT  |    det    |      usda      |
# |      usda      |      usda     |  NOUN |  NNS  |   nsubj   |     argued     |
# |     argued     |     argue     |  VERB |  VBD  |    ROOT   |     argued     |
# |      the       |      the      |  DET  |   DT  |    det    |  advertising   |
# |  advertising   |  advertising  |  NOUN |   NN  |   nsubj   |      was       |
# |      was       |       be      |  AUX  |  VBD  |   ccomp   |     argued     |
# |   government   |   government  |  NOUN |   NN  |  compound |     speech     |
# |     speech     |     speech    |  NOUN |   NN  |    attr   |      was       |
# |     immune     |     immune    |  ADJ  |   JJ  |    amod   |     speech     |
# |      from      |      from     |  ADP  |   IN  |    prep   |     immune     |
# |     first      |     first     |  ADJ  |   JJ  |    amod   |   challenge    |
# |   amendment    |   amendment   |  NOUN |   NN  |  compound |   challenge    |
# |   challenge    |   challenge   |  NOUN |   NN  |    pobj   |      from      |
# |       .        |       .       | PUNCT |   .   |   punct   |     argued     |
# |    another     |    another    |  DET  |   DT  |    det    |     group      |
# |     group      |     group     |  NOUN |   NN  |   nsubj   |     sided      |
# |       of       |       of      |  ADP  |   IN  |    prep   |     group      |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |   producers    |
# |   producers    |    producer   |  NOUN |  NNS  |    pobj   |       of       |
# |       ,        |       ,       | PUNCT |   ,   |   punct   |     group      |
# |      the       |      the      |  DET  |   DT  |    det    |   cattlemen    |
# |    nebraska    |    nebraska   | PROPN |  NNP  |  compound |   cattlemen    |
# |   cattlemen    |   cattleman   |  NOUN |  NNS  |   appos   |     group      |
# |       ,        |       ,       | PUNCT |   ,   |   punct   |     group      |
# |     sided      |      side     |  VERB |  VBD  |    ROOT   |     sided      |
# |      with      |      with     |  ADP  |   IN  |    prep   |     sided      |
# |      the       |      the      |  DET  |   DT  |    det    |      usda      |
# |      usda      |      usda     |  NOUN |  NNS  |    pobj   |      with      |
# |      and       |      and      | CCONJ |   CC  |     cc    |     sided      |
# |      sued      |      sue      |  VERB |  VBD  |    conj   |     sided      |
# |      the       |      the      |  DET  |   DT  |    det    |  association   |
# |   livestock    |   livestock   |  NOUN |   NN  |  compound |   marketing    |
# |   marketing    |   marketing   |  NOUN |   NN  |  compound |  association   |
# |  association   |  association  |  NOUN |   NN  |    dobj   |      sued      |
# |       .        |       .       | PUNCT |   .   |   punct   |     sided      |
# |      the       |      the      |  DET  |   DT  |    det    |     cases      |
# |      two       |      two      |  NUM  |   CD  |   nummod  |     cases      |
# |     cases      |      case     |  NOUN |  NNS  | nsubjpass |  consolidated  |
# |      were      |       be      |  AUX  |  VBD  |  auxpass  |  consolidated  |
# |  consolidated  |  consolidate  |  VERB |  VBN  |    ROOT   |  consolidated  |
# |       .        |       .       | PUNCT |   .   |   punct   |  consolidated  |
# |      the       |      the      |  DET  |   DT  |    det    |     court      |
# |    district    |    district   |  NOUN |   NN  |  compound |     court      |
# |     court      |     court     |  NOUN |   NN  |   nsubj   |     ruled      |
# |      and       |      and      | CCONJ |   CC  |     cc    |     court      |
# |      the       |      the      |  DET  |   DT  |    det    |     court      |
# |     eighth     |     eighth    |  ADJ  |   JJ  |    amod   |     court      |
# |    circuit     |    circuit    |  NOUN |   NN  |  compound |     court      |
# |     court      |     court     |  NOUN |   NN  |    conj   |     court      |
# |       of       |       of      |  ADP  |   IN  |    prep   |     court      |
# |    appeals     |     appeal    |  NOUN |  NNS  |    pobj   |       of       |
# |     ruled      |      rule     |  VERB |  VBD  |    ROOT   |     ruled      |
# |      the       |      the      |  DET  |   DT  |    det    |    program     |
# |    program     |    program    |  NOUN |   NN  |   nsubj   |    violated    |
# |    violated    |    violate    |  VERB |  VBD  |   ccomp   |     ruled      |
# |      the       |      the      |  DET  |   DT  |    det    |   amendment    |
# |     first      |     first     |  ADJ  |   JJ  |    amod   |   amendment    |
# |   amendment    |   amendment   |  NOUN |   NN  |    dobj   |    violated    |
# |      and       |      and      | CCONJ |   CC  |     cc    |    violated    |
# |      that      |      that     | SCONJ |   IN  |    mark   |   compelled    |
# |      the       |      the      |  DET  |   DT  |    det    |  advertising   |
# |  advertising   |  advertising  |  NOUN |   NN  | nsubjpass |   compelled    |
# |      was       |       be      |  AUX  |  VBD  |  auxpass  |   compelled    |
# |   compelled    |     compel    |  VERB |  VBN  |    conj   |    violated    |
# |      and       |      and      | CCONJ |   CC  |     cc    |   compelled    |
# |      not       |      not      |  PART |   RB  |    neg    |     speech     |
# |   government   |   government  |  NOUN |   NN  |  compound |     speech     |
# |     speech     |     speech    |  NOUN |   NN  |    conj   |   compelled    |
# |       .        |       .       | PUNCT |   .   |   punct   |     ruled      |
# |                |               | SPACE |  _SP  |    dep    |       .        |
# |                |               |       |       |           |                |
# +----------------+---------------+-------+-------+-----------+----------------+

# %%
print(' '.join([token.text for token in fact_token if 'subj' in token.dep_]))
print(' '.join([token.text for token in fact_token if 'obj' in token.dep_]))
# Out:
# producers producers association producers usda advertising group cases court program advertising
# fee advertisements behalf industry advertisements department agriculture court fee advertising which amendment right speech challenge producers usda association appeals amendment

# %%
re.findall('usda', fact)
# Out:
# ['usda', 'usda', 'usda']

# %%
print(fact)
# Out:
# the beef promotion and research act (1985) required cattle producers to pay a fee for generic beef advertisements done on behalf of the cattle industry. some cattle producers disagreed with the advertisements. the livestock marketing association sued the department of agriculture (usda) in federal district court and alleged a government-required fee for advertising with which some cattle producers disagreed violated their first amendment right to free speech. the usda argued the advertising was government speech immune from first amendment challenge. another group of cattle producers, the nebraska cattlemen, sided with the usda and sued the livestock marketing association. the two cases were consolidated. the district court and the eighth circuit court of appeals ruled the program violated the first amendment and that the advertising was compelled and not government speech.

# %%
print(get_name_re(first_party, fact_token))
print(fact)
# Out:
# on march 12 , 2003 , firstparty was scheduled to undergo cataract surgery performed by lieutenant commander frank bishop , m.d . , a united states navy surgeon in guam . firstparty previously gave his written consent to the procedure but claims that he attempted to orally withdraw it prior to the surgery . he suffered complications from the surgery and faces continuing treatment with unclear likelihood of success . firstparty sued dr . bishop for battery and negligent medical malpractice . the united states substituted itself for dr . bishop and filed a motion for summary judgment . the district court granted summary judgment for the negligent medical malpractice claim , not the battery claim . the united states then filed for dismissal of the battery claim and alleged that the federal tort claims act preserved sovereign immunity against battery claims . the district court dismissed the claim . the united states court of appeals for the ninth circuit affirmed .
#
# on march 12, 2003, steven levin was scheduled to undergo cataract surgery performed by lieutenant commander frank bishop, m.d., a united states navy surgeon in guam. levin previously gave his written consent to the procedure but claims that he attempted to orally withdraw it prior to the surgery. he suffered complications from the surgery and faces continuing treatment with unclear likelihood of success. levin sued dr. bishop for battery and negligent medical malpractice. the united states substituted itself for dr. bishop and filed a motion for summary judgment. the district court granted summary judgment for the negligent medical malpractice claim, not the battery claim. the united states then filed for dismissal of the battery claim and alleged that the federal tort claims act preserved sovereign immunity against battery claims. the district court dismissed the claim. the united states court of appeals for the ninth circuit affirmed.

# %%
print(get_name_re(second_party, fact_token, first=False))
print(fact)
# Out:
# on march 12, 2003, steven levin was scheduled to undergo cataract surgery performed by lieutenant commander frank bishop, m.d., a secondparty navy surgeon in guam. levin previously gave his written consent to the procedure but claims that he attempted to orally withdraw it prior to the surgery. he suffered complications from the surgery and faces continuing treatment with unclear likelihood of success. levin sued dr. bishop for battery and negligent medical malpractice. the secondparty substituted itself for dr. bishop and filed a motion for summary judgment. the district court granted summary judgment for the negligent medical malpractice claim, not the battery claim. the secondparty then filed for dismissal of the battery claim and alleged that the federal tort claims act preserved sovereign immunity against battery claims. the district court dismissed the claim. the secondparty court of appeals for the ninth circuit affirmed.
#
# on march 12, 2003, steven levin was scheduled to undergo cataract surgery performed by lieutenant commander frank bishop, m.d., a united states navy surgeon in guam. levin previously gave his written consent to the procedure but claims that he attempted to orally withdraw it prior to the surgery. he suffered complications from the surgery and faces continuing treatment with unclear likelihood of success. levin sued dr. bishop for battery and negligent medical malpractice. the united states substituted itself for dr. bishop and filed a motion for summary judgment. the district court granted summary judgment for the negligent medical malpractice claim, not the battery claim. the united states then filed for dismissal of the battery claim and alleged that the federal tort claims act preserved sovereign immunity against battery claims. the district court dismissed the claim. the united states court of appeals for the ninth circuit affirmed.

# %%
replace_name(first_party, second_party, fact_token)
# Out:
# 'on 12 , 2003 , firstparty was scheduled to undergo performed by , , a secondparty in . firstparty previously gave his written to the but claims that he attempted to orally withdraw it prior to the . he suffered from the and faces continuing with unclear of . firstparty sued for and negligent medical . the secondparty substituted itself for and filed a for . the granted for the negligent medical , not the . the secondparty then filed for of the and alleged that the federal act preserved sovereign against . the dismissed the . the secondparty of for the ninth affirmed . \n'

# %%
table = prettytable.PrettyTable()
table.field_names = ['Token', 'Lemma', 'POS', 'Tag', 'Dep', "HEAD"]

for token in nlp(get_name_re(first_party, fact_token)):
    table.add_row([token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.head.text])

print(table)
# Out:
# changed name: []
# changed name: []
# changed name: []
# changed name: ['agriculture (usda)']
# changed name: []
# name list: ['mike', 'johanns', 'secretary', 'agriculture', 'usda']
# fact subj: beef promotion research act cattle producers fee beef advertisements behalf cattle industry cattle producers advertisements livestock marketing association department agriculture usda district court government fee advertising cattle producers amendment right speech usda advertising government speech amendment challenge group cattle producers nebraska cattlemen usda livestock marketing association cases district court circuit court appeals program amendment advertising government speech
# [('mike', 0), ('johanns', 0), ('secretary', 0), ('agriculture', 1), ('usda', 3)]
# +----------------+---------------+-------+-------+-----------+----------------+
# |     Token      |     Lemma     |  POS  |  Tag  |    Dep    |      HEAD      |
# +----------------+---------------+-------+-------+-----------+----------------+
# |      the       |      the      |  DET  |   DT  |    det    |   promotion    |
# |      beef      |      beef     |  NOUN |   NN  |  compound |   promotion    |
# |   promotion    |   promotion   |  NOUN |   NN  |    nmod   |   producers    |
# |      and       |      and      | CCONJ |   CC  |     cc    |   promotion    |
# |    research    |    research   |  NOUN |   NN  |  compound |      act       |
# |      act       |      act      |  NOUN |   NN  |    conj   |   promotion    |
# |       (        |       (       | PUNCT | -LRB- |   punct   |   promotion    |
# |      1985      |      1985     |  NUM  |   CD  |   appos   |   promotion    |
# |       )        |       )       | PUNCT | -RRB- |   punct   |   promotion    |
# |    required    |    require    |  VERB |  VBN  |    amod   |   producers    |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |   producers    |
# |   producers    |    producer   |  NOUN |  NNS  |   nsubj   |      pay       |
# |       to       |       to      |  PART |   TO  |    aux    |      pay       |
# |      pay       |      pay      |  VERB |   VB  |    ROOT   |      pay       |
# |       a        |       a       |  DET  |   DT  |    det    |      fee       |
# |      fee       |      fee      |  NOUN |   NN  |    dobj   |      pay       |
# |      for       |      for      |  ADP  |   IN  |    prep   |      fee       |
# |    generic     |    generic    |  ADJ  |   JJ  |    amod   |      beef      |
# |      beef      |      beef     |  NOUN |   NN  |  compound | advertisements |
# | advertisements | advertisement |  NOUN |  NNS  |    pobj   |      for       |
# |      done      |       do      |  VERB |  VBN  |    acl    | advertisements |
# |       on       |       on      |  ADP  |   IN  |    prep   |      done      |
# |     behalf     |     behalf    |  NOUN |   NN  |    pobj   |       on       |
# |       of       |       of      |  ADP  |   IN  |    prep   |     behalf     |
# |      the       |      the      |  DET  |   DT  |    det    |    industry    |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |    industry    |
# |    industry    |    industry   |  NOUN |   NN  |    pobj   |       of       |
# |       .        |       .       | PUNCT |   .   |   punct   |      pay       |
# |      some      |      some     |  DET  |   DT  |    det    |   producers    |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |   producers    |
# |   producers    |    producer   |  NOUN |  NNS  |   nsubj   |   disagreed    |
# |   disagreed    |    disagree   |  VERB |  VBD  |    ROOT   |   disagreed    |
# |      with      |      with     |  ADP  |   IN  |    prep   |   disagreed    |
# |      the       |      the      |  DET  |   DT  |    det    | advertisements |
# | advertisements | advertisement |  NOUN |  NNS  |    pobj   |      with      |
# |       .        |       .       | PUNCT |   .   |   punct   |   disagreed    |
# |      the       |      the      |  DET  |   DT  |    det    |  association   |
# |   livestock    |   livestock   |  NOUN |   NN  |  compound |   marketing    |
# |   marketing    |   marketing   |  NOUN |   NN  |  compound |  association   |
# |  association   |  association  |  NOUN |   NN  |   nsubj   |      sued      |
# |      sued      |      sue      |  VERB |  VBD  |    ROOT   |      sued      |
# |      the       |      the      |  DET  |   DT  |    det    |   department   |
# |   department   |   department  |  NOUN |   NN  |    dobj   |      sued      |
# |       of       |       of      |  ADP  |   IN  |    prep   |   department   |
# |   firstparty   |   firstparty  |  NOUN |   NN  |    pobj   |       of       |
# |       (        |       (       | PUNCT | -LRB- |   punct   |   firstparty   |
# |   firstparty   |   firstparty  |  NOUN |   NN  |   appos   |   firstparty   |
# |       )        |       )       | PUNCT | -RRB- |   punct   |   firstparty   |
# |       in       |       in      |  ADP  |   IN  |    prep   |      sued      |
# |    federal     |    federal    |  ADJ  |   JJ  |    amod   |     court      |
# |    district    |    district   |  NOUN |   NN  |  compound |     court      |
# |     court      |     court     |  NOUN |   NN  |    pobj   |       in       |
# |      and       |      and      | CCONJ |   CC  |     cc    |      sued      |
# |    alleged     |     allege    |  VERB |  VBD  |    conj   |      sued      |
# |       a        |       a       |  DET  |   DT  |    det    |      fee       |
# |   government   |   government  |  NOUN |   NN  |  npadvmod |    required    |
# |       -        |       -       | PUNCT |  HYPH |   punct   |    required    |
# |    required    |    require    |  VERB |  VBN  |    amod   |      fee       |
# |      fee       |      fee      |  NOUN |   NN  |    dobj   |    alleged     |
# |      for       |      for      |  ADP  |   IN  |    prep   |      fee       |
# |  advertising   |  advertising  |  NOUN |   NN  |    pobj   |      for       |
# |      with      |      with     |  ADP  |   IN  |    prep   |   disagreed    |
# |     which      |     which     |  PRON |  WDT  |    pobj   |      with      |
# |      some      |      some     |  DET  |   DT  |    det    |   producers    |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |   producers    |
# |   producers    |    producer   |  NOUN |  NNS  |   nsubj   |   disagreed    |
# |   disagreed    |    disagree   |  VERB |  VBD  |   relcl   |      fee       |
# |    violated    |    violate    |  VERB |  VBD  |   ccomp   |    alleged     |
# |     their      |     their     |  PRON |  PRP$ |    poss   |   amendment    |
# |     first      |     first     |  ADJ  |   JJ  |    amod   |   amendment    |
# |   amendment    |   amendment   |  NOUN |   NN  |    dobj   |    violated    |
# |     right      |     right     |  NOUN |   NN  |    dobj   |    violated    |
# |       to       |       to      |  ADP  |   IN  |    prep   |     right      |
# |      free      |      free     |  ADJ  |   JJ  |    amod   |     speech     |
# |     speech     |     speech    |  NOUN |   NN  |    pobj   |       to       |
# |       .        |       .       | PUNCT |   .   |   punct   |      sued      |
# |      the       |      the      |  DET  |   DT  |    det    |   firstparty   |
# |   firstparty   |   firstparty  |  NOUN |   NN  |   nsubj   |     argued     |
# |     argued     |     argue     |  VERB |  VBD  |    ROOT   |     argued     |
# |      the       |      the      |  DET  |   DT  |    det    |  advertising   |
# |  advertising   |  advertising  |  NOUN |   NN  |   nsubj   |      was       |
# |      was       |       be      |  AUX  |  VBD  |   ccomp   |     argued     |
# |   government   |   government  |  NOUN |   NN  |  compound |     speech     |
# |     speech     |     speech    |  NOUN |   NN  |    attr   |      was       |
# |     immune     |     immune    |  ADJ  |   JJ  |    amod   |     speech     |
# |      from      |      from     |  ADP  |   IN  |    prep   |     immune     |
# |     first      |     first     |  ADJ  |   JJ  |    amod   |   challenge    |
# |   amendment    |   amendment   |  NOUN |   NN  |  compound |   challenge    |
# |   challenge    |   challenge   |  NOUN |   NN  |    pobj   |      from      |
# |       .        |       .       | PUNCT |   .   |   punct   |     argued     |
# |    another     |    another    |  DET  |   DT  |    det    |     group      |
# |     group      |     group     |  NOUN |   NN  |   nsubj   |     sided      |
# |       of       |       of      |  ADP  |   IN  |    prep   |     group      |
# |     cattle     |     cattle    |  NOUN |  NNS  |  compound |   producers    |
# |   producers    |    producer   |  NOUN |  NNS  |    pobj   |       of       |
# |       ,        |       ,       | PUNCT |   ,   |   punct   |     group      |
# |      the       |      the      |  DET  |   DT  |    det    |   cattlemen    |
# |    nebraska    |    nebraska   | PROPN |  NNP  |  compound |   cattlemen    |
# |   cattlemen    |   cattleman   |  NOUN |  NNS  |   appos   |     group      |
# |       ,        |       ,       | PUNCT |   ,   |   punct   |     group      |
# |     sided      |      side     |  VERB |  VBD  |    ROOT   |     sided      |
# |      with      |      with     |  ADP  |   IN  |    prep   |     sided      |
# |      the       |      the      |  DET  |   DT  |    det    |   firstparty   |
# |   firstparty   |   firstparty  |  NOUN |   NN  |    pobj   |      with      |
# |      and       |      and      | CCONJ |   CC  |     cc    |     sided      |
# |      sued      |      sue      |  VERB |  VBD  |    conj   |     sided      |
# |      the       |      the      |  DET  |   DT  |    det    |  association   |
# |   livestock    |   livestock   |  NOUN |   NN  |  compound |   marketing    |
# |   marketing    |   marketing   |  NOUN |   NN  |  compound |  association   |
# |  association   |  association  |  NOUN |   NN  |    dobj   |      sued      |
# |       .        |       .       | PUNCT |   .   |   punct   |     sided      |
# |      the       |      the      |  DET  |   DT  |    det    |     cases      |
# |      two       |      two      |  NUM  |   CD  |   nummod  |     cases      |
# |     cases      |      case     |  NOUN |  NNS  | nsubjpass |  consolidated  |
# |      were      |       be      |  AUX  |  VBD  |  auxpass  |  consolidated  |
# |  consolidated  |  consolidate  |  VERB |  VBN  |    ROOT   |  consolidated  |
# |       .        |       .       | PUNCT |   .   |   punct   |  consolidated  |
# |      the       |      the      |  DET  |   DT  |    det    |     court      |
# |    district    |    district   |  NOUN |   NN  |  compound |     court      |
# |     court      |     court     |  NOUN |   NN  |   nsubj   |     ruled      |
# |      and       |      and      | CCONJ |   CC  |     cc    |     court      |
# |      the       |      the      |  DET  |   DT  |    det    |     court      |
# |     eighth     |     eighth    |  ADJ  |   JJ  |    amod   |     court      |
# |    circuit     |    circuit    |  NOUN |   NN  |  compound |     court      |
# |     court      |     court     |  NOUN |   NN  |    conj   |     court      |
# |       of       |       of      |  ADP  |   IN  |    prep   |     court      |
# |    appeals     |     appeal    |  NOUN |  NNS  |    pobj   |       of       |
# |     ruled      |      rule     |  VERB |  VBD  |    ROOT   |     ruled      |
# |      the       |      the      |  DET  |   DT  |    det    |    program     |
# |    program     |    program    |  NOUN |   NN  |   nsubj   |    violated    |
# |    violated    |    violate    |  VERB |  VBD  |   ccomp   |     ruled      |
# |      the       |      the      |  DET  |   DT  |    det    |   amendment    |
# |     first      |     first     |  ADJ  |   JJ  |    amod   |   amendment    |
# |   amendment    |   amendment   |  NOUN |   NN  |    dobj   |    violated    |
# |      and       |      and      | CCONJ |   CC  |     cc    |    violated    |
# |      that      |      that     | SCONJ |   IN  |    mark   |   compelled    |
# |      the       |      the      |  DET  |   DT  |    det    |  advertising   |
# |  advertising   |  advertising  |  NOUN |   NN  | nsubjpass |   compelled    |
# |      was       |       be      |  AUX  |  VBD  |  auxpass  |   compelled    |
# |   compelled    |     compel    |  VERB |  VBN  |    conj   |    violated    |
# |      and       |      and      | CCONJ |   CC  |     cc    |   compelled    |
# |      not       |      not      |  PART |   RB  |    neg    |     speech     |
# |   government   |   government  |  NOUN |   NN  |  compound |     speech     |
# |     speech     |     speech    |  NOUN |   NN  |    conj   |   compelled    |
# |       .        |       .       | PUNCT |   .   |   punct   |     ruled      |
# |                |               | SPACE |  _SP  |    dep    |       .        |
# |                |               |       |       |           |                |
# +----------------+---------------+-------+-------+-----------+----------------+

# %%
get_name_re(second_party, fact_token)
# Out:
# name list: ['livestock', 'marketing', 'association', 'nebraska', 'cattlemen', 'inc', 'livestock', 'marketing', 'association']
# fact subj: beef promotion research act cattle producers fee beef advertisements behalf cattle industry cattle producers advertisements livestock marketing association department agriculture usda district court government fee advertising cattle producers amendment right speech usda advertising government speech amendment challenge group cattle producers nebraska cattlemen usda livestock marketing association cases district court circuit court appeals program amendment advertising government speech
# [('livestock', 2),
#  ('marketing', 2),
#  ('association', 2),
#  ('nebraska', 1),
#  ('cattlemen', 1),
#  ('inc', 0),
#  ('livestock', 2),
#  ('marketing', 2),
#  ('association', 2)]

# %% [markdown]
# ### 지금까지 difflib matching의 문제점
# 1. 이름의 구성요소 중 긴 쪽으로만 매칭됨 => ohio & mike agriculture et al의 경우 agriculture로만 매칭

# %% [markdown]
# ### RoBERTa 문제점
# 1. first party, scecond party 구별 불가
# 2. 이름의 경우 높은 확률로 OOV [UNK]로 인식됨

# %% [markdown]
# ### IDEA
#
# 1. most close matching을 찾는다.
# 2. 이름을 다 분리해서 찾는다. (특정 길이 이상만)
# 3. 주어에 해당하는 토큰 중에서만 찾는다.

# %%
train_df['facts'].apply(lambda x: len(x.split())).describe()
# Out:
# count    2475.000000
# mean      174.109899
# std        82.009291
# min        14.000000
# 25%       120.000000
# 50%       164.000000
# 75%       218.000000
# max       932.000000
# Name: facts, dtype: float64

# %%
train_df = train_df[train_df['facts'].apply(lambda x: len(x.split())) >= 10]

# %%
from light

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=250, stop_words='english')
X = vectorizer.fit_transform(train_df['new_facts'])

# %%
y = train_df['first_party_winner']

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X, y, stratify=y)

# %%
from sklearn.svm import SVC

svc = SVC(kernel='rbf')
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score, classification_report

y_pred = svc.predict(X_valid)
print(accuracy_score(y_valid, y_pred))
# Out:
# 0.6623586429725363

# %%
print(classification_report(y_valid, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       207
#            1       0.66      1.00      0.80       412
#
#     accuracy                           0.66       619
#    macro avg       0.33      0.50      0.40       619
# weighted avg       0.44      0.66      0.53       619

# %%
y_train.mean()
# Out:
# 0.6654094827586207

# %%
X_test = vectorizer.transform(test_df['new_facts'])

# %%
y_pred = knn.predict(X_test)
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
y_pred.mean()
# Out:
# 0.7193548387096774

# %%
submission = pd.DataFrame({'ID': test_df['ID'], 'first_party_winner': y_pred})
submission
# Out:
#              ID  first_party_winner
# 0     TEST_0000                   1
# 1     TEST_0001                   1
# 2     TEST_0002                   0
# 3     TEST_0003                   0
# 4     TEST_0004                   0
# ...         ...                 ...
# 1235  TEST_1235                   0
# 1236  TEST_1236                   0
# 1237  TEST_1237                   1
# 1238  TEST_1238                   1
# 1239  TEST_1239                   1
#
# [1240 rows x 2 columns]

# %%
submission.to_csv("ml_submission.csv", index=False)

# %% [markdown]
# ### 문제점
#
# 1. 이름의 인코딩이 불완전하다.

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=50)
X_pca = pca.fit_transform(X.toarray())

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(X_pca, y, stratify=y)

# %%
from sklearn.svm import SVC

svc = SVC(kernel='rbf')
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
from sklearn.metrics import accuracy_score

y_pred = knn.predict(X_valid)
print(accuracy_score(y_valid, y_pred))
# Out:
# 0.6403225806451613
