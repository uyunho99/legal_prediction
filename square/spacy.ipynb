# %% [markdown]
# ## Word statistics

# %%
import spacy
import pandas as pd
import prettytable

# %%
train_df = pd.read_csv('./Data/train.csv')

idx = 0
first_party = train_df.loc[idx, 'first_party'].lower()
second_party = train_df.loc[idx, 'second_party'].lower()
fact = train_df.loc[idx, 'facts'].lower()

nlp = spacy.load('en_core_web_sm')
doc = nlp(fact)

print(fact)
print(first_party)
print(second_party)
# Out:
# on june 27, 1962, phil st. amant, a candidate for public office, made a television speech in baton rouge, louisiana.  during this speech, st. amant accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union.  finally, st. amant implicated herman thompson, an east baton rouge deputy sheriff, in a scheme to move money between the teamsters union and st. amant’s political opponent.
# thompson successfully sued st. amant for defamation.  louisiana’s first circuit court of appeals reversed, holding that thompson did not show st. amant acted with “malice.”  thompson then appealed to the supreme court of louisiana.  that court held that, although public figures forfeit some of their first amendment protection from defamation, st. amant accused thompson of a crime with utter disregard of whether the remarks were true.  finally, that court held that the first amendment protects uninhibited, robust debate, rather than an open season to shoot down the good name of anyone who happens to be a public servant.
#
# phil a. st. amant
# herman a. thompson

# %%
list(doc.sents)
# Out:
# [on june 27, 1962, phil st. amant, a candidate for public office, made a television speech in baton rouge, louisiana.  ,
#  during this speech, st. amant accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union.  ,
#  finally, st. amant implicated herman thompson, an east baton rouge deputy sheriff, in a scheme to move money between the teamsters union and st. amant’s political opponent. ,
#  thompson successfully sued st. amant for defamation.  ,
#  louisiana’s first circuit court of appeals reversed, holding that thompson did not show st. amant acted with “malice.”  ,
#  thompson then appealed to the supreme court of louisiana.  ,
#  that court held that, although public figures forfeit some of their first amendment protection from defamation, st. amant accused thompson of a crime with utter disregard of whether the remarks were true.  ,
#  finally, that court held that the first amendment protects uninhibited, robust debate, rather than an open season to shoot down the good name of anyone who happens to be a public servant. ]

# %%
sen_table = prettytable.PrettyTable()
sen_table.field_names = ['Token', 'Lemma', 'POS', 'Tag', 'Dep', "HEAD"]

for token in doc:
    sen_table.add_row([token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.head.text])

print(sen_table)
# Out:
# +--------------+--------------+-------+------+----------+------------+
# |    Token     |    Lemma     |  POS  | Tag  |   Dep    |    HEAD    |
# +--------------+--------------+-------+------+----------+------------+
# |      on      |      on      |  ADP  |  IN  |   prep   |    made    |
# |     june     |     june     | PROPN | NNP  |   pobj   |     on     |
# |      27      |      27      |  NUM  |  CD  |  nummod  |    june    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |    june    |
# |     1962     |     1962     |  NUM  |  CD  |  nummod  |    june    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |    made    |
# |     phil     |     phil     | PROPN | NNP  | compound |     st     |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   |    made    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   amant    |
# |      a       |      a       |  DET  |  DT  |   det    | candidate  |
# |  candidate   |  candidate   |  NOUN |  NN  |  appos   |   amant    |
# |     for      |     for      |  ADP  |  IN  |   prep   | candidate  |
# |    public    |    public    |  ADJ  |  JJ  |   amod   |   office   |
# |    office    |    office    |  NOUN |  NN  |   pobj   |    for     |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   amant    |
# |     made     |     make     |  VERB | VBD  |   ROOT   |    made    |
# |      a       |      a       |  DET  |  DT  |   det    |   speech   |
# |  television  |  television  |  NOUN |  NN  | compound |   speech   |
# |    speech    |    speech    |  NOUN |  NN  |   dobj   |    made    |
# |      in      |      in      |  ADP  |  IN  |   prep   |   speech   |
# |    baton     |    baton     | PROPN | NNP  | compound |   rouge    |
# |    rouge     |    rouge     | PROPN | NNP  |   pobj   |     in     |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   rouge    |
# |  louisiana   |  louisiana   | PROPN | NNP  |  appos   |   rouge    |
# |      .       |      .       | PUNCT |  .   |  punct   |    made    |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |    during    |    during    |  ADP  |  IN  |   prep   |  accused   |
# |     this     |     this     |  DET  |  DT  |   det    |   speech   |
# |    speech    |    speech    |  NOUN |  NN  |   pobj   |   during   |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  accused   |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   |  accused   |
# |   accused    |    accuse    |  VERB | VBD  |   ROOT   |  accused   |
# |     his      |     his      |  PRON | PRP$ |   poss   |  opponent  |
# |  political   |  political   |  ADJ  |  JJ  |   amod   |  opponent  |
# |   opponent   |   opponent   |  NOUN |  NN  |   dobj   |  accused   |
# |      of      |      of      |  ADP  |  IN  |   prep   |  opponent  |
# |    being     |      be      |  AUX  | VBG  |  pcomp   |     of     |
# |      a       |      a       |  DET  |  DT  |   det    | communist  |
# |  communist   |  communist   |  NOUN |  NN  |   attr   |   being    |
# |     and      |     and      | CCONJ |  CC  |    cc    |     of     |
# |      of      |      of      |  ADP  |  IN  |   conj   |     of     |
# |    being     |      be      |  AUX  | VBG  | auxpass  |  involved  |
# |   involved   |   involve    |  VERB | VBN  |  pcomp   |     of     |
# |      in      |      in      |  ADP  |  IN  |   prep   |  involved  |
# |   criminal   |   criminal   |  ADJ  |  JJ  |   amod   | activities |
# |  activities  |   activity   |  NOUN | NNS  |   pobj   |     in     |
# |     with     |     with     |  ADP  |  IN  |   prep   |  involved  |
# |     the      |     the      |  DET  |  DT  |   det    |    head    |
# |     head     |     head     |  NOUN |  NN  |   pobj   |    with    |
# |      of      |      of      |  ADP  |  IN  |   prep   |    head    |
# |     the      |     the      |  DET  |  DT  |   det    |   union    |
# |    local     |    local     |  ADJ  |  JJ  |   amod   |   union    |
# |  teamsters   |   teamster   |  NOUN | NNS  | compound |   union    |
# |    union     |    union     |  NOUN |  NN  |   pobj   |     of     |
# |      .       |      .       | PUNCT |  .   |  punct   |  accused   |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |   finally    |   finally    |  ADV  |  RB  |  advmod  | implicated |
# |      ,       |      ,       | PUNCT |  ,   |  punct   | implicated |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   | implicated |
# |  implicated  |  implicate   |  VERB | VBD  |   ROOT   | implicated |
# |    herman    |    herman    | PROPN | NNP  | compound |  thompson  |
# |   thompson   |   thompson   | PROPN | NNP  |   dobj   | implicated |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  thompson  |
# |      an      |      an      |  DET  |  DT  |   det    |  sheriff   |
# |     east     |     east     | PROPN | NNP  | compound |   baton    |
# |    baton     |    baton     | PROPN | NNP  | compound |  sheriff   |
# |    rouge     |    rouge     | PROPN | NNP  | compound |  sheriff   |
# |    deputy    |    deputy    | PROPN | NNP  | compound |  sheriff   |
# |   sheriff    |   sheriff    |  NOUN |  NN  |  appos   |  thompson  |
# |      ,       |      ,       | PUNCT |  ,   |  punct   | implicated |
# |      in      |      in      |  ADP  |  IN  |   prep   | implicated |
# |      a       |      a       |  DET  |  DT  |   det    |   scheme   |
# |    scheme    |    scheme    |  NOUN |  NN  |   pobj   |     in     |
# |      to      |      to      |  PART |  TO  |   aux    |    move    |
# |     move     |     move     |  VERB |  VB  |   acl    |   scheme   |
# |    money     |    money     |  NOUN |  NN  |   dobj   |    move    |
# |   between    |   between    |  ADP  |  IN  |   prep   |    move    |
# |     the      |     the      |  DET  |  DT  |   det    |   union    |
# |  teamsters   |   teamster   |  NOUN | NNS  | compound |   union    |
# |    union     |    union     | PROPN | NNP  |   pobj   |  between   |
# |     and      |     and      | CCONJ |  CC  |    cc    |   union    |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |   poss   |  opponent  |
# |      ’s      |      ’s      |  PART | POS  |   case   |   amant    |
# |  political   |  political   |  ADJ  |  JJ  |   amod   |  opponent  |
# |   opponent   |   opponent   |  NOUN |  NN  |   conj   |   union    |
# |      .       |      .       | PUNCT |  .   |  punct   | implicated |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |              |              |       |      |          |            |
# |   thompson   |   thompson   | PROPN | NNP  |  nsubj   |    sued    |
# | successfully | successfully |  ADV  |  RB  |  advmod  |    sued    |
# |     sued     |     sue      |  VERB | VBD  |   ROOT   |    sued    |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |   dobj   |    sued    |
# |     for      |     for      |  ADP  |  IN  |   prep   |   amant    |
# |  defamation  |  defamation  |  NOUN |  NN  |   pobj   |    for     |
# |      .       |      .       | PUNCT |  .   |  punct   |    sued    |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |  louisiana   |  louisiana   | PROPN | NNP  |   poss   |   court    |
# |      ’s      |      ’s      |  PART | POS  |   case   | louisiana  |
# |    first     |    first     |  ADJ  |  JJ  |   amod   |   court    |
# |   circuit    |   circuit    | PROPN | NNP  | compound |   court    |
# |    court     |    court     | PROPN | NNP  |  nsubj   |  reversed  |
# |      of      |      of      |  ADP  |  IN  |   prep   |   court    |
# |   appeals    |    appeal    |  NOUN | NNS  |   pobj   |     of     |
# |   reversed   |   reverse    |  VERB | VBD  |   ROOT   |  reversed  |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  reversed  |
# |   holding    |     hold     |  VERB | VBG  |  csubj   |    show    |
# |     that     |     that     |  DET  |  DT  |   det    |  thompson  |
# |   thompson   |   thompson   |  NOUN |  NN  |   dobj   |  holding   |
# |     did      |      do      |  AUX  | VBD  |   aux    |    show    |
# |     not      |     not      |  PART |  RB  |   neg    |    show    |
# |     show     |     show     |  VERB |  VB  |  ccomp   |  reversed  |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   |   acted    |
# |    acted     |     act      |  VERB | VBD  |  ccomp   |    show    |
# |     with     |     with     |  ADP  |  IN  |   prep   |   acted    |
# |      “       |      "       | PUNCT |  ``  |  punct   |    with    |
# |    malice    |    malice    |  NOUN |  NN  |   pobj   |    with    |
# |      .       |      .       | PUNCT |  .   |  punct   |  reversed  |
# |      ”       |      "       | PUNCT |  ''  |  punct   |  reversed  |
# |              |              | SPACE | _SP  |   dep    |     ”      |
# |   thompson   |   thompson   | PROPN | NNP  |  nsubj   |  appealed  |
# |     then     |     then     |  ADV  |  RB  |  advmod  |  appealed  |
# |   appealed   |    appeal    |  VERB | VBD  |   ROOT   |  appealed  |
# |      to      |      to      |  ADP  |  IN  |   prep   |  appealed  |
# |     the      |     the      |  DET  |  DT  |   det    |   court    |
# |   supreme    |   supreme    | PROPN | NNP  | compound |   court    |
# |    court     |    court     | PROPN | NNP  |   pobj   |     to     |
# |      of      |      of      |  ADP  |  IN  |   prep   |   court    |
# |  louisiana   |  louisiana   | PROPN | NNP  |   pobj   |     of     |
# |      .       |      .       | PUNCT |  .   |  punct   |  appealed  |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |     that     |     that     |  DET  |  DT  |   det    |   court    |
# |    court     |    court     |  NOUN |  NN  |  nsubj   |    held    |
# |     held     |     hold     |  VERB | VBD  |   ROOT   |    held    |
# |     that     |     that     | SCONJ |  IN  |   mark   |  accused   |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  accused   |
# |   although   |   although   | SCONJ |  IN  |   mark   |  forfeit   |
# |    public    |    public    |  ADJ  |  JJ  |   amod   |  figures   |
# |   figures    |    figure    |  NOUN | NNS  |  nsubj   |  forfeit   |
# |   forfeit    |   forfeit    |  ADP  |  IN  |  advcl   |  accused   |
# |     some     |     some     |  PRON |  DT  |   dobj   |  forfeit   |
# |      of      |      of      |  ADP  |  IN  |   prep   |    some    |
# |    their     |    their     |  PRON | PRP$ |   poss   | protection |
# |    first     |    first     |  ADJ  |  JJ  |   amod   | protection |
# |  amendment   |  amendment   |  NOUN |  NN  | compound | protection |
# |  protection  |  protection  |  NOUN |  NN  |   pobj   |     of     |
# |     from     |     from     |  ADP  |  IN  |   prep   | protection |
# |  defamation  |  defamation  |  NOUN |  NN  |   pobj   |    from    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  accused   |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   |  accused   |
# |   accused    |    accuse    |  VERB | VBD  |  ccomp   |    held    |
# |   thompson   |   thompson   |  NOUN |  NN  |   dobj   |  accused   |
# |      of      |      of      |  ADP  |  IN  |   prep   |  accused   |
# |      a       |      a       |  DET  |  DT  |   det    |   crime    |
# |    crime     |    crime     |  NOUN |  NN  |   pobj   |     of     |
# |     with     |     with     |  ADP  |  IN  |   prep   |   crime    |
# |    utter     |    utter     |  ADJ  |  JJ  |   amod   | disregard  |
# |  disregard   |  disregard   |  NOUN |  NN  |   pobj   |    with    |
# |      of      |      of      |  ADP  |  IN  |   prep   | disregard  |
# |   whether    |   whether    | SCONJ |  IN  |   mark   |    were    |
# |     the      |     the      |  DET  |  DT  |   det    |  remarks   |
# |   remarks    |    remark    |  NOUN | NNS  |  nsubj   |    were    |
# |     were     |      be      |  AUX  | VBD  |  pcomp   |     of     |
# |     true     |     true     |  ADJ  |  JJ  |  acomp   |    were    |
# |      .       |      .       | PUNCT |  .   |  punct   |    held    |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |   finally    |   finally    |  ADV  |  RB  |  advmod  |    held    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |    held    |
# |     that     |     that     |  DET  |  DT  |   det    |   court    |
# |    court     |    court     |  NOUN |  NN  |  nsubj   |    held    |
# |     held     |     hold     |  VERB | VBD  |   ROOT   |    held    |
# |     that     |     that     | SCONJ |  IN  |   mark   |  protects  |
# |     the      |     the      |  DET  |  DT  |   det    | amendment  |
# |    first     |    first     |  ADJ  |  JJ  |   amod   | amendment  |
# |  amendment   |  amendment   |  NOUN |  NN  |  nsubj   |  protects  |
# |   protects   |   protect    |  VERB | VBZ  |  ccomp   |    held    |
# | uninhibited  | uninhibited  |  ADJ  |  JJ  |   amod   |   debate   |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   debate   |
# |    robust    |    robust    |  ADJ  |  JJ  |   amod   |   debate   |
# |    debate    |    debate    |  NOUN |  NN  |   dobj   |  protects  |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   debate   |
# |    rather    |    rather    |  ADV  |  RB  |  advmod  |    than    |
# |     than     |     than     |  ADP  |  IN  |    cc    |   debate   |
# |      an      |      an      |  DET  |  DT  |   det    |   season   |
# |     open     |     open     |  ADJ  |  JJ  |   amod   |   season   |
# |    season    |    season    |  NOUN |  NN  |   conj   |   debate   |
# |      to      |      to      |  PART |  TO  |   aux    |   shoot    |
# |    shoot     |    shoot     |  VERB |  VB  |  relcl   |   season   |
# |     down     |     down     |  ADP  |  RP  |   prt    |   shoot    |
# |     the      |     the      |  DET  |  DT  |   det    |    name    |
# |     good     |     good     |  ADJ  |  JJ  |   amod   |    name    |
# |     name     |     name     |  NOUN |  NN  |   dobj   |   shoot    |
# |      of      |      of      |  ADP  |  IN  |   prep   |    name    |
# |    anyone    |    anyone    |  PRON |  NN  |   pobj   |     of     |
# |     who      |     who      |  PRON |  WP  |  nsubj   |  happens   |
# |   happens    |    happen    |  VERB | VBZ  |  relcl   |   anyone   |
# |      to      |      to      |  PART |  TO  |   aux    |     be     |
# |      be      |      be      |  AUX  |  VB  |  xcomp   |  happens   |
# |      a       |      a       |  DET  |  DT  |   det    |  servant   |
# |    public    |    public    |  ADJ  |  JJ  |   amod   |  servant   |
# |   servant    |   servant    |  NOUN |  NN  |   attr   |     be     |
# |      .       |      .       | PUNCT |  .   |  punct   |    held    |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |              |              |       |      |          |            |
# +--------------+--------------+-------+------+----------+------------+

# %%
verb_table = prettytable.PrettyTable()
verb_table.field_names = ['Token', 'Lemma', 'POS', 'Tag', 'Dep', "HEAD"]

for token in doc:
    if token.pos_ == 'VERB':
        verb_table.add_row([token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.head.text])

print(verb_table)
# Out:
# +------------+-----------+------+-----+-------+------------+
# |   Token    |   Lemma   | POS  | Tag |  Dep  |    HEAD    |
# +------------+-----------+------+-----+-------+------------+
# |    made    |    make   | VERB | VBD |  ROOT |    made    |
# |  accused   |   accuse  | VERB | VBD |  ROOT |  accused   |
# |  involved  |  involve  | VERB | VBN | pcomp |     of     |
# | implicated | implicate | VERB | VBD |  ROOT | implicated |
# |    move    |    move   | VERB |  VB |  acl  |   scheme   |
# |    sued    |    sue    | VERB | VBD |  ROOT |    sued    |
# |  reversed  |  reverse  | VERB | VBD |  ROOT |  reversed  |
# |  holding   |    hold   | VERB | VBG | csubj |    show    |
# |    show    |    show   | VERB |  VB | ccomp |  reversed  |
# |   acted    |    act    | VERB | VBD | ccomp |    show    |
# |  appealed  |   appeal  | VERB | VBD |  ROOT |  appealed  |
# |    held    |    hold   | VERB | VBD |  ROOT |    held    |
# |  accused   |   accuse  | VERB | VBD | ccomp |    held    |
# |    held    |    hold   | VERB | VBD |  ROOT |    held    |
# |  protects  |  protect  | VERB | VBZ | ccomp |    held    |
# |   shoot    |   shoot   | VERB |  VB | relcl |   season   |
# |  happens   |   happen  | VERB | VBZ | relcl |   anyone   |
# +------------+-----------+------+-----+-------+------------+

# %%
import spacy
import pandas as pd

train_df = pd.read_csv('./Data/train.csv')

nlp = spacy.load('en_core_web_sm')

verb_list = []
verb_info_list = []

for fact in train_df['facts']:
    doc = nlp(fact.lower())
    for token in doc:
        if token.pos_ == 'VERB':
            verb_list.append(token.lemma_)
            verb_info = {'lemma': token.lemma_, 'dependency': token.dep_}  # Save as a dictionary
            verb_info_list.append(verb_info)

# %%
print(verb_list)
# Out:
# ['make', 'accuse', 'involve', 'implicate', 'move', 'sue', 'reverse', 'hold', 'show', 'act', 'appeal', 'hold', 'accuse', 'hold', 'protect', 'shoot', 'happen', 'ride', 'suffer', 'identify', 'try', 'convict', 'carry', 'crack', 'rule', 'try', 'knock', 'find', 'sentence', 'file', 'violate', 'argue', 'base', 'infer', 'deny', 'appeal', 'reverse', 'hold', 'violate', 'adjudicate', 'base', 'present', 'convict', 'sentence', 'grant', 'uphold', 'instruct', 'look', 'mitigate', 'resentence', 'resentence', 'sentence', 'file', 'argue', 'apply', 'lack', 'grant', 'vacate', 'reverse', 'hold', 'raise', 'raise', 'hold', 'fail', 'raise', 'decide', 'convict', 'obtain', 'concern', 'apply', 'state', 'deny', 'obtain', 'argue', 'base', 'break', 'struggle', 'seize', 'flee', 'have', 'identify', 'apprehend', 'hold', 'question', 'place', 'limit', 'confess', 'lead', 'confess', 'question', 'admit', 'testify', 'regard', 'surround', 'rule', 'subject', 'convict', 'sentence', 'affirm', 'allow', 'construct', 'operate', 'help', 'compensate', 'promise', 'receive', 'permit', 'charge', 'receive', 'meet', 'adopt', 'require', 'flow', 'pass', 'operate', 'avoid', 'pay', 'truck', 'process', 'carry', 'crash', 'discover', 'violate', 'sue', 'respond', 'sue', 'claim', 'violate', 'disrupt', 'agree', 'dissolve', 'rule', 'require', 'detain', 'release', 'demonstrate', 'detain', 'sue', 'argue', 'prolong', 'justify', 'violate', 'regard', 'grant', 'require', 'provide', 'release', 'show', 'justify', 'hold', 'prolong', 'raise', 'interpret', 'have', 'entitle', 'prove', 'succeed', 'affirm', 'move', 'grant', 'affirm', 'determine', 'consider', 'entitle', 'injure', 'work', 'handle', 'invoke', 'transfer', 'demand', 'become', 'base', 'lose', 'file', 'prohibit', 'discriminate', 'perform', 'demonstrate', 'impose', 'grant', 'find', 'alter', 'result', 'nondisable', 'reverse', 'hold', 'require', 'determine', 'constitute', 'charge', 'attempt', 'stem', 'fail', 'use', 'exclude', 'challenge', 'hold', 'make', 'show', 'use', 'give', 'allow', 'give', 'exclude', 'find', 'motivate', 'give', 'discover', 'have', 'fill', 'lose', 'find', 'sentence', 'find', 'err', 'exclude', 'uphold', 'appeal', 'argue', 'hear', 'violate', 'find', 'adjudicate', 'determine', 'use', 'violate', 'review', 'find', 'violate', 'determine', 'apply', 'set', 'ask', 'have', 'find', 'hear', 'deprive', 'prevail', 'have', 'prohibit', 'serve', 'file', 'sue', 'disqualify', 'hold', 'violate', 'remain', 'elect', 'reverse', 'hold', 'restrict', 'hold', 'maintain', 'justify', 'fall', 'sell', 'fall', 'charge', 'require', 'sell', 'prohibit', 'sell', 'permit', 'purchase', 'file', 'allege', 'fall', 'violate', 'amend', 'find', 'establish', 'reject', 'fall', 'provide', 'rebut', 'establish', 'make', 'meet', 'affirm', 'file', 'seek', 'comply', 'find', 'apply', 'dismiss', 'file', 'consolidate', 'concern', 'use', 'require', 'advocate', 'enforce', 'require', 'apply', 'sign', 'declare', 'engage', 'prohibit', 'deny', 'refuse', 'agree', 'pay', 'sue', 'argue', 'require', 'agree', 'violate', 'uphold', 'uphold', 'hold', 'violate', 'exclude', 'reverse', 'sue', 'challenge', 'recognize', 'occur', 'provide', 'argue', 'violate', 'bring', 'find', 'reverse', 'hold', 'recognize', 'perform', 'violate', 'name', 'bring', 'define', 'allege', 'violate', 'breach', 'cause', 'engage', 'prohibit', 'argue', 'prohibit', 'suffer', 'become', 'file', 'dismiss', 'grant', 'permit', 'proceed', 'engage', 'prohibit', 'invest', 'become', 'contain', 'need', 'meet', 'raise', 'suffer', 'move', 'dismiss', 'grant', 'find', 'lack', 'award', 'prevail', 'affirm', 'provide', 'improve', 'undertake', 'lead', 'increase', 'take', 'make', 'provide', 'compile', 'collect', 'admit', 'die', 'deny', 'occur', 'grant', 'seek', 'assert', 'fail', 'install', 'seek', 'protect', 'hold', 'exceed', 'allow', 'withhold', 'educate', 'decide', 'name', 'charge', 'convict', 'distribute', 'determine', 'use', 'give', 'base', 'hold', 'decide', 'want', 'apply', 'remand', 'grant', 'remand', 'hold', 'abuse', 'vary', 'create', 'hold' ...

# %%
from collections import Counter

stat_verb_list = Counter(verb_list).most_common()
stat_verb_list[:25]
# Out:
# [('hold', 1652),
#  ('file', 1160),
#  ('find', 1099),
#  ('argue', 1057),
#  ('affirm', 1042),
#  ('violate', 981),
#  ('deny', 896),
#  ('have', 839),
#  ('reverse', 753),
#  ('grant', 741),
#  ('require', 692),
#  ('sue', 642),
#  ('dismiss', 630),
#  ('allege', 611),
#  ('appeal', 574),
#  ('rule', 574),
#  ('convict', 552),
#  ('claim', 539),
#  ('make', 520),
#  ('seek', 505),
#  ('apply', 504),
#  ('use', 487),
#  ('provide', 454),
#  ('base', 422),
#  ('allow', 407)]

# %%
verb_info_df = pd.DataFrame(verb_info_list)
verb_info_df
# Out:
#            lemma dependency
# 0           make       ROOT
# 1         accuse       ROOT
# 2        involve      pcomp
# 3      implicate       ROOT
# 4           move        acl
# ...          ...        ...
# 56316   infringe      ccomp
# 56317     direct       ROOT
# 56318      track      xcomp
# 56319        use      advcl
# 56320       hold       ROOT
#
# [56321 rows x 2 columns]

# %%
verb_info_df['dependency'].value_counts()
# Out:
# dependency
# ROOT         17421
# conj          6936
# advcl         6762
# ccomp         6194
# acl           5044
# xcomp         3805
# relcl         3607
# pcomp         2566
# amod          2308
# prep           658
# pobj           223
# csubj          149
# acomp          133
# compound       125
# nsubj          104
# dobj            92
# parataxis       48
# nmod            28
# dep             27
# poss            19
# oprd            13
# nsubjpass       12
# punct           10
# appos            9
# csubjpass        5
# dative           5
# attr             4
# advmod           3
# npadvmod         3
# meta             3
# cc               2
# case             2
# auxpass          1
# Name: count, dtype: int64

# %%
verb_root_df = verb_info_df[verb_info_df['dependency'] == 'ROOT']
verb_root_df
# Out:
#            lemma dependency
# 0           make       ROOT
# 1         accuse       ROOT
# 3      implicate       ROOT
# 5            sue       ROOT
# 6        reverse       ROOT
# ...          ...        ...
# 56306   maintain       ROOT
# 56309        use       ROOT
# 56315       find       ROOT
# 56317     direct       ROOT
# 56320       hold       ROOT
#
# [17421 rows x 2 columns]

# %%
verb_root_stat = verb_root_df['lemma'].value_counts()
print(verb_root_stat[:25])
# Out:
# lemma
# file         797
# affirm       767
# hold         754
# argue        555
# find         525
# sue          489
# deny         487
# appeal       439
# reverse      422
# grant        417
# rule         331
# convict      314
# move         261
# dismiss      252
# seek         226
# claim        206
# agree        199
# reject       191
# challenge    186
# require      170
# have         167
# charge       164
# bring        164
# allege       163
# arrest       160
# Name: count, dtype: int64

# %% [markdown]
# ## Party Encoding

# %%
import re
import pandas as pd
import string

# %%
train_df = pd.read_csv("./Data/train.csv")
test_df = pd.read_csv("./Data/test.csv")

# %%
train_df['first_party'] = train_df['first_party'].str.lower()
train_df['second_party'] = train_df['second_party'].str.lower()
train_df['facts'] = train_df['facts'].str.lower()

test_df['first_party'] = test_df['first_party'].str.lower()
test_df['second_party'] = test_df['second_party'].str.lower()
test_df['facts'] = test_df['facts'].str.lower()

# %%
def get_name_re(name, fact_token: spacy.tokens.doc.Doc, first=True):
    name = re.sub(rf'[ .,{string.punctuation}]+', r' ', name.lower())
    name_list = [n for n in name.split() if len(n) >= 1]

    for n in name_list:
        changed_name = re.findall(rf"{n} ?\([a-z]+\)", fact_token.text)
        # print(f"changed name: {changed_name}")
        if changed_name:
            name_list.extend([re.sub(rf'({n}|[ {string.punctuation}])', '', cn) for cn in changed_name])

    # fact_subj = ' '.join([token.text for token in fact_token if 'NN' in token.tag_])
    # print(f"name list: {name_list}")
    # print(f"fact subj: {fact_subj}")
    # res = []
    # for name in name_list:
    #     res.append((name, len(re.findall(name, fact_subj))))
    # print(res)
    abbrev = "firstparty" if first else "secondparty"
    fact_subj = []
    for token in fact_token:
        if 'NN' in token.tag_ and token.text in name_list:
            fact_subj.append(abbrev)
        else:
            fact_subj.append(token.text)
    fact_subj = ' '.join(fact_subj)
    # fact_subj = re.sub(rf"({'|'.join(name_list)})", abbrev, fact)
    fact_subj = re.sub(rf"({abbrev} ?)+", f'{abbrev} ', fact_subj)
    return fact_subj

# %%
import re

def replace_name(first_party, second_party, fact_token: spacy.tokens.doc.Doc):
    first_party_name = re.sub(rf'[ .,{string.punctuation}]+', r' ', first_party.lower())
    second_party_name = re.sub(rf'[ .,{string.punctuation}]+', r' ', second_party.lower())
    fp_name_list = [n for n in first_party_name.split() if len(n) >= 1]
    sp_name_list = [n for n in second_party_name.split() if len(n) >= 1]

    fp_name_list_added = fp_name_list.copy()
    sp_name_list_added = sp_name_list.copy()

    for n in fp_name_list:
        changed_name = re.findall(rf"{n} ?\([a-z]+\)", fact_token.text)
        if changed_name:
            fp_name_list_added.extend([re.sub(rf'({n}|[ {string.punctuation}])', '', cn) for cn in changed_name])
    
    for n in sp_name_list:
        changed_name = re.findall(rf"{n} ?\([a-z]+\)", fact_token.text)
        if changed_name:
            sp_name_list_added.extend([re.sub(rf'({n}|[ {string.punctuation}])', '', cn) for cn in changed_name])

    # for name_list in [fp_name_list, sp_name_list]:
    #     for n in name_list:
    #         changed_name = re.findall(rf"{n} ?\([a-z]+\)", fact_token.text)
    #         if changed_name:
    #             name_list.extend([re.sub(rf'({n}|[ {string.punctuation}])', '', cn) for cn in changed_name])
    
    # print(f"fp name list: {fp_name_list}")
    # print(f"sp name list: {sp_name_list}")

    fact_subj = []
    for token in fact_token:
        if 'NN' in token.tag_:
            if token.text in fp_name_list_added:
                fact_subj.append('firstparty')
            elif token.text in sp_name_list_added:
                fact_subj.append('secondparty')
            else:
                fact_subj.append(token.text)
        else:
            fact_subj.append(token.text)
    
    fact_subj = ' '.join(fact_subj)
    fact_subj = re.sub(rf"(firstparty ?)+", f'firstparty ', fact_subj)
    fact_subj = re.sub(rf"(secondparty ?)+", f'secondparty ', fact_subj)
    return fact_subj

# %%
from pandarallel import pandarallel

pandarallel.initialize(progress_bar=True, nb_workers=2)

# train_df['facts_token'] = train_df['facts'].parallel_apply(nlp)
train_df['new_facts'] = train_df.parallel_apply(lambda x: replace_name(x['first_party'], x['second_party'], nlp(x['facts'])), axis=1)
# Out:
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=1239), Label(value='0 / 1239'))), …

# %%
train_df.head()
# Out:
#            ID         first_party                    second_party
# 0  TRAIN_0000   phil a. st. amant              herman a. thompson  \
# 1  TRAIN_0001      stephen duncan                  lawrence owens
# 2  TRAIN_0002   billy joe magwood  tony patterson, warden, et al.
# 3  TRAIN_0003          linkletter                          walker
# 4  TRAIN_0004  william earl fikes                         alabama
#
#                                                facts  first_party_winner
# 0  on june 27, 1962, phil st. amant, a candidate ...                   1  \
# 1  ramon nelson was riding his bike when he suffe...                   0
# 2  an alabama state court convicted billy joe mag...                   1
# 3  victor linkletter was convicted in state court...                   0
# 4  on april 24, 1953 in selma, alabama, an intrud...                   1
#
#                                            new_facts
# 0  on june 27 , 1962 , firstparty . firstparty , ...
# 1  ramon nelson was riding his bike when he suffe...
# 2  an alabama state court convicted billy firstpa...
# 3  victor firstparty was convicted in state court...
# 4  on april 24 , 1953 in selma , secondparty , an...

# %%
nlp = spacy.load('en_core_web_sm')

enc_verb_list = []
enc_verb_info_list = []

for fact in train_df['new_facts']:
    doc = nlp(fact.lower())
    for token in doc:
        if token.pos_ == 'VERB':
            enc_verb_list.append(token.lemma_)
            verb_info = {'lemma': token.lemma_, 'dependency': token.dep_}  # Save as a dictionary
            enc_verb_info_list.append(verb_info)

# %%
from collections import Counter

stat_enc_verb_list = Counter(enc_verb_list).most_common()
stat_enc_verb_list[:25]
# Out:
# [('hold', 1656),
#  ('file', 1160),
#  ('affirm', 1127),
#  ('find', 1106),
#  ('argue', 1057),
#  ('violate', 981),
#  ('deny', 896),
#  ('have', 838),
#  ('reverse', 758),
#  ('grant', 741),
#  ('require', 691),
#  ('sue', 643),
#  ('dismiss', 630),
#  ('allege', 618),
#  ('appeal', 579),
#  ('rule', 574),
#  ('convict', 553),
#  ('claim', 535),
#  ('make', 520),
#  ('seek', 506),
#  ('apply', 504),
#  ('use', 486),
#  ('provide', 454),
#  ('base', 422),
#  ('allow', 407)]

# %%
enc_verb_info_df = pd.DataFrame(enc_verb_info_list)
enc_verb_info_df
# Out:
#            lemma dependency
# 0           make       ROOT
# 1         accuse       ROOT
# 2        involve      pcomp
# 3      implicate       ROOT
# 4           move        acl
# ...          ...        ...
# 56556     direct       ROOT
# 56557      track      xcomp
# 56558        use      advcl
# 56559     affirm      pcomp
# 56560       hold       ROOT
#
# [56561 rows x 2 columns]

# %%
enc_verb_info_df['dependency'].value_counts()
# Out:
# dependency
# ROOT         17602
# conj          7025
# advcl         6798
# ccomp         6004
# acl           5062
# xcomp         3815
# relcl         3557
# pcomp         2744
# amod          2374
# prep           674
# csubj          161
# pobj           115
# compound       107
# acomp          104
# nsubj           95
# dobj            91
# punct           43
# dep             42
# parataxis       35
# nmod            30
# nsubjpass       16
# oprd            14
# appos           11
# poss             9
# npadvmod         7
# csubjpass        7
# case             6
# meta             4
# dative           3
# advmod           3
# prt              1
# auxpass          1
# intj             1
# Name: count, dtype: int64

# %%
enc_verb_root_df = enc_verb_info_df[enc_verb_info_df['dependency'] == 'ROOT']
enc_verb_root_df
# Out:
#            lemma dependency
# 0           make       ROOT
# 1         accuse       ROOT
# 3      implicate       ROOT
# 5            sue       ROOT
# 6        reverse       ROOT
# ...          ...        ...
# 56545   maintain       ROOT
# 56548        use       ROOT
# 56554       find       ROOT
# 56556     direct       ROOT
# 56560       hold       ROOT
#
# [17602 rows x 2 columns]

# %%
print(train_df['facts'][0])
print(train_df['new_facts'][0])
# Out:
# on june 27, 1962, phil st. amant, a candidate for public office, made a television speech in baton rouge, louisiana.  during this speech, st. amant accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union.  finally, st. amant implicated herman thompson, an east baton rouge deputy sheriff, in a scheme to move money between the teamsters union and st. amant’s political opponent.
# thompson successfully sued st. amant for defamation.  louisiana’s first circuit court of appeals reversed, holding that thompson did not show st. amant acted with “malice.”  thompson then appealed to the supreme court of louisiana.  that court held that, although public figures forfeit some of their first amendment protection from defamation, st. amant accused thompson of a crime with utter disregard of whether the remarks were true.  finally, that court held that the first amendment protects uninhibited, robust debate, rather than an open season to shoot down the good name of anyone who happens to be a public servant.
#
# on june 27 , 1962 , firstparty . firstparty , a candidate for public office , made a television speech in baton rouge , louisiana .   during this speech , firstparty . firstparty accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union .   finally , firstparty . firstparty implicated secondparty , an east baton rouge deputy sheriff , in a scheme to move money between the teamsters union and firstparty . firstparty ’s political opponent .
#  secondparty successfully sued firstparty . firstparty for defamation .   louisiana ’s first circuit court of appeals reversed , holding that secondparty did not show firstparty . firstparty acted with “ malice . ”   secondparty then appealed to the supreme court of louisiana .   that court held that , although public figures forfeit some of their first amendment protection from defamation , firstparty . firstparty accused secondparty of a crime with utter disregard of whether the remarks were true .   finally , that court held that the first amendment protects uninhibited , robust debate , rather than an open season to shoot down the good name of anyone who happens to be a public servant .

# %%
# Define the list of words you are interested in
words_of_interest = ['firstparty', 'secondparty']  # replace these with your actual words

sentences_with_words = []

for fact in train_df['new_facts']:
    doc = nlp(fact.lower())
    for sent in doc.sents:  # spacy splits the document into sentences
        if any(word in sent.text for word in words_of_interest):
            sentences_with_words.append(sent.text)
            
sentences_with_words
# Out:
# ['on june 27 , 1962 , firstparty .',
#  'firstparty , a candidate for public office , made a television speech in baton rouge , louisiana .   ',
#  'during this speech , firstparty .',
#  'firstparty accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union .   ',
#  'finally , firstparty .',
#  'firstparty implicated secondparty , an east baton rouge deputy sheriff , in a scheme to move money between the teamsters union and firstparty .',
#  'firstparty ’s political opponent . \n ',
#  'secondparty successfully sued firstparty .',
#  'firstparty for defamation .   ',
#  'louisiana ’s first circuit court of appeals reversed , holding that secondparty did not show firstparty .',
#  'firstparty acted with “ malice . ”   ',
#  'secondparty then appealed to the supreme court of louisiana .   ',
#  'that court held that , although public figures forfeit some of their first amendment protection from defamation , firstparty .',
#  'firstparty accused secondparty of a crime with utter disregard of whether the remarks were true .   ',
#  'after two eyewitnesses identified secondparty from an array of photos and then a lineup , he was tried and convicted for nelson ’s death .',
#  'because nelson was carrying cocaine and crack cocaine potentially for distribution , the judge at secondparty ’ bench trial ruled that secondparty was probably also a drug dealer and was trying to “ knock [ nelson ] off . ”',
#  'secondparty was found guilty of first - degree murder and sentenced to 25 years in prison . \n ',
#  'secondparty filed a petition for a writ of habeas corpus on the grounds that his constitutional right to due process was violated during the trial .',
#  'the district court denied the writ of habeas corpus , and secondparty appealed .',
#  'the u.s . court of appeals for the seventh circuit reversed the denial and held that the trial judge ’s inference about secondparty ’s motive violated his right to have his guilt adjudicated solely based on the evidence presented at trial . \n',
#  'an alabama state court convicted billy firstparty of murder and sentenced him to death .',
#  "subsequently , an alabama federal district court partially granted mr . firstparty 's petition for federal habeas corpus relief .",
#  'the court upheld his conviction but instructed the state court to look at mitigating evidence when resentencing mr . firstparty .',
#  'firstparty to death once again .',
#  'mr . firstparty filed a second petition for federal habeas corpus relief with the federal district court arguing that a judicial rule was retroactively applied in his case and that he lacked effective counsel at sentencing .',
#  "firstparty 's death sentence . \n ",
#  "the court also held that mr . firstparty 's counsel was not ineffective because he failed to raise an argument that had already been decided by the state 's highest court adverse to his client 's position . \n",
#  'victor firstparty was convicted in state court on evidence illegally obtained by police prior to the supreme court decision concerning the fourth amendment in mapp v. ohio .',
#  'firstparty argued for a retrial based on the mapp decision . \n',
#  'on april 24 , 1953 in selma , secondparty , an intruder broke into the apartment of the daughter of the city mayor .',
#  'the police apprehended firstparty on the basis of a call from a private citizen and held him “ on an open charge of investigation . ”',
#  'the police questioned firstparty for hours , placed him in jail , and limited his access to anyone familiar .',
#  'after nearly a week of this treatment , firstparty confessed in the form of answers to the interrogator ’s leading questions .',
#  'five days later , firstparty confessed under questioning a second time .',
#  'when these confessions were admitted into the trial as evidence , firstparty did not testify regarding the events surrounding his interrogation because the judge had ruled he would be subjected to unlimited cross - examination .',
#  'the jury convicted firstparty and sentenced him to death .',
#  'the supreme court of secondparty affirmed . \n',
#  'a new york secondparty , secondparty , allowed a contractor to construct and operate a waste processing plant within secondparty limits .',
#  'secondparty promised that the plant would receive 120,000 tons of solid waste each year , and permitted the contractor to charge an $ 81 " tipping fee " for each ton received .',
#  'to meet the 120,000 ton quota , secondparty adopted a " flow control ordinance . "',
#  'the ordinance required that all solid waste flowing into and out of the secondparty pass through the new plant .',
#  'firstparty & a firstparty , firstparty .',
#  'operated a similar plant within the secondparty .',
#  'to avoid paying the $ 81 fee , firstparty trucked processed waste directly to an indiana landfill .',
#  'in 1991 , a firstparty truck carrying illegal waste crashed and police discovered that firstparty was violating the ordinance .',
#  'secondparty sued firstparty in a new york supreme court .',
#  'firstparty responded by suing secondparty in a federal district court , claiming that the ordinance violated the commerce clause by disrupting interstate commerce .',
#  'the district court agreed but dissolved its injunction against secondparty when the new york supreme court ruled in favor of secondparty . \n',
#  'secondparty and other detained noncitizens sued and argued that their prolonged detention without hearings and determinations to justify the detentions violated their due process rights .',
#  'in 1990 , robert secondparty injured his back while working in a cargo - handling position at firstparty .',
#  'invoking his seniority rights , secondparty transferred to a less physically demanding position in the mailroom .',
#  "subsequently , secondparty 's new position became open to seniority - based employee bidding under firstparty ' seniority system and , ultimately , he lost his job .",
#  'secondparty then filed suit under the americans with disabilities act of 1990 ( ada ) , which prohibits an employer from discriminating against " an individual with a disability " who with " reasonable accommodation " can perform a job \'s essential functions unless the employer " can demonstrate that the accommodation would impose an undue hardship on the operation of [ its ] business . "',
#  'in granting us firstparty summary judgment , the district court found that altering a seniority system would result in an " undue hardship " to both firstparty and its nondisabled employees .',
#  'secondparty , a hispanic man , was charged with three counts of murder and one count of attempted murder stemming from a failed robbery .',
#  "secondparty challenged the prosecution 's use of preemptory challenges as a violation of the supreme court 's decision in batson v. kentucky , which held that the exclusion of jurors on the basis of race was a violation of the equal protection clause of the fourteenth amendment .",
#  "the state court allowed the prosecution to give their non - racially motivated reasons in a closed hearing , from which secondparty and his attorneys were excluded , and subsequently found the prosecution 's use of preemptory challenges was not racially motivated .",
#  "secondparty was not given the prosecution 's reasoning or a transcript of the meeting until after the conclusion of his trial .",
#  'secondparty was found guilty of the majority of the charges against him and sentenced to death . \n ',
#  "on appeal , the california supreme court found that the state court erred in excluding secondparty from the batson hearing , but that error as well as the loss of the questionnaires were harmless , and therefore upheld secondparty 's conviction .",
#  'secondparty appealed to the u.s court of appeals for the ninth circuit and argued that the batson hearing procedure and loss of the questionnaires violated his constitutional rights .',
#  "in accordance with the antiterrorism and effective death penalty act of 1996 , the appellate court found that the california supreme court had not adjudicated secondparty 's claims of federal constitutional violations on the merits largely on the basis that the california court had determined the procedure used for the batson hearing violated california state law ; therefore the appellate court reviewed secondparty 's claims de novo and found that the exclusion of secondparty from the batson hearing , as well as the loss of the questionnaires , violated secondparty 's constitutional rights .",
#  "to determine whether the errors were harmless , the court of appeals applied the standard set forth in   brecht v. abrahamson , which asked whether the errors had a substantial and injurious influence on the jury 's verdict , and found that the exclusion of secondparty from the batson   hearing deprived him of the ability to prevail on a compelling batson challenge . \n",
#  'in 1977 , firstparty a. firstparty , a baptist minister , filed as a candidate for the state constitutional convention .',
#  'another candidate , selma secondparty , sued for a declaratory judgment that firstparty was disqualified .',
#  'firstparty ’s name remained on the ballot and he was elected .',
#  'from 1972 through 1978 , falls firstparty , firstparty .',
#  'sold beer to secondparty , firstparty .',
#  ', the sole wholesale distributor for firstparty in indiana at a higher price than falls firstparty charged its only wholesale distributor in kentucky .',
#  "secondparty filed suit , alleging that falls firstparty 's price discrimination violated section 2(a ) of the clayton act , as amended by the robinson - patman act .",
#  'the federal court found that secondparty had established a prima facie case of price discrimination .',
#  'the court rejected falls firstparty \'s " meeting - competition " defense under section 2(b ) of the clayton act , which provides that a defendant may rebut a prima facie showing of illegal price discrimination by establishing that its lower price to any purchaser or purchasers was made in good faith to meet an equally low price of a competitor .',
#  "voters and candidates in mississippi and virginia filed four separate cases seeking judgments that certain amendments to their states ' election laws and procedures were subject to the pre - approval requirements of section 5 of the voting rights act of 1965 , and hence were not enforceable until the secondparty complied with the requirements .",
#  'in both cases , the firstparty assessor denied tax exemption because the churches refused to agree to the oath .   ',
#  'the churches paid their taxes under protest and sued the secondparty of firstparty for a refund .   ',
#  "groups of same - sex couples sued their relevant state agencies in secondparty , michigan , kentucky , and tennessee to challenge the constitutionality of those states ' bans on same - sex marriage or refusal to recognize legal same - sex marriages that occurred in jurisdictions that provided for such marriages .",
#  'named plaintiff firstparty and others brought a class action lawsuit against u.s . secondparty and other over alleged mismanagement of a defined benefit pension plan between 2007 and 2010 .',
#  "in 1996 , ignacio secondparty 's wife died in an automobile accident in a firstparty , washington intersection .",
#  'secondparty first sought information on the intersection and then asserted that the state had been negligent in failing to install proper traffic controls .',
#  'in 2004 , firstparty was charged and convicted of conspiracy to distribute at least 50 grams of crack cocaine and 500 grams of powder cocaine .',
#  'the district court determined that the 100:1 weight ratio for sentencing crack cocaine and powder cocaine that the secondparty sentencing commission guidelines manual ( guidelines ) used was excessive given the circumstances , so the district court instead based its ruling on a 20:1 ratio .',
#  'the u.s . court of appeals for the eighth circuit held that the district court could not decide what ratio it wanted to apply for conviction and remanded firstparty case for retrial and sentencing .',
#  'the supreme court granted certiorari and remanded the case for reconsideration in light of the court ’s decision in kimbrough v. secondparty , in which the court held that the guidelines were advisory and that a district court does not abuse its discretion by varying from the guidelines ’ prescribed ratio due to disagreement with the disparity the guidelines create between crack cocaine and powder cocaine .',
#  'abel secondparty - secondparty was charged with a variety of federal narcotics and weapons offenses .',
#  "after prospective juror don gilbert indicated several times that he would favor the prosecution , martinez- secondparty 's counsel challenged him for cause .",
#  'after twice objecting , unsuccessfully , to the for - cause ruling , secondparty - secondparty used a peremptory challenge to remove him .',
#  'subsequently , secondparty - secondparty exhausted all of his peremptory challenges .',
#  "thereafter , secondparty - secondparty 's counsel did not object to the final seating of the jurors .",
#  'secondparty - secondparty was then convicted on all counts .',
#  'on appeal , secondparty - secondparty argued that the district court abused its discretion in refusing to strike gilbert for cause and that this error used one of his peremptory challenges wrongly .',
#  "ultimately , the court found that the district court 's error resulted in a violation of martinez- secondparty 's fifth amendment due process rights because it forced him to use a peremptory challenge curatively , which impaired his right to a full complement of peremptory challenges .",
#  'three members of the firstparty family were involved in a head - on collision with another vehicle .',
#  'firstparty and alexa wore lap / shoulder seatbelts and survived , while thanh wore a lap - only seatbelt and died .',
#  'subsequently , they sued secondparty of secondparty for strict products liability , negligence , deceit , and wrongful death in a california state court .',
#  '47 , louisville , kentucky , denied the application of cassius firstparty , also known as muhammad ali , for classification as a conscientious objector .',
#  'firstparty then took an administrative appeal to the kentucky appeal board , which tentatively classified him i - a , or eligible for unrestricted military service , and referred his file to the justice department for an advisory recommendation .',
#  "the justice department concluded , contrary to a hearing officer 's recommendation , that firstparty 's claim should be denied .",
#  'the department wrote that firstparty did not meet any of the three basic tests for conscientious objector status ; that he is conscientiously opposed to war in any form , that this opposition is based upon religious training and belief , and that this objection is sincere .',
#  "subsequently , the appeal board denied firstparty 's claim , but without stating its reasons .",
#  'when firstparty refused to report for induction , he was tried and convicted of willful refusal to submit to induction .',
#  'in the meantime , maher became engaged to bassam firstparty ’s sister and michael began to share some of the insider information he received from his brother with firstparty .',
#  'firstparty did not directly trade through his own accounts but went through his brother - in - law , karim bayyouk .',
#  'as a result , firstparty ’s account reached $ 2.1 million .',
#  'firstparty was charged with conspiracy to commit securities fraud and insider trading in 2011 and found guilty .',
#  'the appellate court found that , because of the close family relationship , there was sufficient evidence that firstparty knew he was trading on insider information . \n',
#  'the state of secondparty threatened to enforce its anti - fish trapping law against two local native american tribes .   ',
#  'the president of the firstparty council was arrested while trying to moor a trap .   ',
#  'the tribes sued to enjoin secondparty from enforcing the anti - trapping law .   ',
#  'the district court dismissed the suit and the supreme court of secondparty affirmed . \n',
#  'in december 1980 , the firstparty state police force was conducting an authorized wiretap on the telephone of paul driscoll .',
#  'on december 20 , the police intercepted two phone calls from an unknown source that made reference to marijuana use that had occurred at a party the previous night at the secondparty ’ residence .',
#  'firstparty was the police officer in charge of the driscoll investigation , and on the basis of these two calls , he drew up felony charges for the secondparty .',
#  'the charges were presented to a state district court judge in february 1981 , and the judge signed warrants for the secondparty ’ arrest .',
#  'the secondparty were arrested in their home on march 19 , 1981 , and taken to a police station where they were booked and held for several hours before being released .',
#  'the secondparty sued firstparty in district court and alleged that his application for the warrants for their arrest violated their fourth and fourteenth amendment rights .',
#  'after the evidence was presented to the jury , firstparty moved for a direct verdict , which the district court granted .',
#  'secondparty owned a private dude ranch which was intermingled with federal lands .',
#  'the previous owner had granted the bureau of land management ( blm ) right - of - way across the private land , but after secondparty bought the ranch he refused to re - grant it .',
#  'secondparty alleged that blm officials harassed him with threats and meritless criminal charges , with the aim of forcing him to grant the government right - of - way .',
#  'secondparty sued the blm officials for extortion in violation of the racketeer influenced and corrupt organizations act ( rico ) .',
#  'secondparty argued that the fifth amendment protects a " right to exclude " government officials from one \'s property , and that the blm agents had retaliated against him for his exercise of this right .',
#  'in 1967 , congress appropriated funds to the firstparty ( firstparty ) to build the tellico dam .   ',
#  'although the multi - million dollar project was almost completed , the project predated the esa , and congress continued to appropriate funds to the project after the esa passed , secondparty sued to enjoin the completion of the dam in order to protect the snail darter .   ',
#  'christopher lee secondparty and others were indicted on federal charges of " conspiring to possess with intent to distribute more than 50 grams of cocaine base ( crack ) and conspiring to distribute the same . "',
#  'the federal bureau of alcohol , tobacco , and firearms had monitored secondparty and others prior to their indictment and arrest .',
#  'secondparty filed a motion for discovery or dismissal , alleging that he was selected for prosecution because he was black .',
#  'firstparty company provides charge card services to supermarkets and other merchants throughout the united states .',
#  'when a store decides to accept firstparty cards , it must enter into a card acceptance agreement .',
#  'this standard form contract outlines the basic relationship between firstparty and the merchant .',
#  'a clause within the agreement requires arbitration of all claims brought against firstparty and prohibits merchants from bringing any class action claims . \n ',
#  'several merchants , including italian secondparty , brought individual lawsuits against firstparty , claiming that the card acceptance agreement violates u.s . antitrust laws .',
#  'the united states district court for the southern district of new york consolidated the cases and firstparty moved to dismiss in order to force the merchants to arbitrate .',
#  'the merchants appealed and the united states court of appeals for the second circuit held that the arbitration clause , in particular the class action waiver , is unenforceable because it would essentially protect firstparty from antitrust suits .',
#  'firstparty express further appealed and the united states supreme court granted certiorari .',
#  'on june 1 , 1975 , three men entered a restaurant in little rock , secondparty , and proceeded to rob and terrorize the five employees .',
#  'the ensuing police investigation resulted in the arrest of the firstparty , ray lee welch , and gary don campbell .',
#  'the secondparty supreme court affirmed . \n',
#  ', a dutch corporation , sued central secondparty of secondparty in u.s . district court for the southern district of new york for breaching a letter of credit .   ',
#  'central secondparty moved to dismiss the case due to lack of subject matter jurisdiction .   ',
#  'the district court dismissed the case , holding that central secondparty had sovereign immunity .   ',
#  'secondparty and secondparty counties adopted a local " flow control " ordinance requiring locally - produced garbage to be delivered to local publicly - owned facilities .',
#  'the firstparty filed suit in federal district court , arguing that by prohibiting the export of secondparty and preventing secondparty firstparty from using less expensive out - of - state facilities , the ordinance ran afoul of the dormant commerce clause .',
#  'the district court ruled against firstparty and held that the ordinance was constitutional because it did not discriminate against out - of - state businesses . \n ',
#  'in the fort laramie treaty of 1868 , the firstparty granted the secondparty indian secondparty the great secondparty reservation , including the black hills of south dakota .',
#  'the secondparty requested compensation in 1920 .',
#  'the firstparty court of claims ruled against the secondparty in 1942 .',
#  'the commission ruled that the secondparty was not barred by the court of claims decision and ruled that congress used its powers of eminent domain in 1877 and the secondparty were therefore entitled to compensation .',
#  'the court of claims maintained that the secondparty were barred by their first case .',
#  'the court of claims then held that the secondparty were entitled to $ 17.1 million . \n',
#  'firstparty and his fiancée - then - wife , miriam regalado , worked for secondparty , the owner and operator of a stainless steel manufacturing facility in carroll county , ky .',
#  'on february 13 , 2003 , the eeoc notified secondparty of the charge .',
#  "slightly more than three weeks later , secondparty terminated firstparty 's employment .",
#  "firstparty filed a complaint , which alleged that he was fired in retaliation for regalado 's eeoc charge .",
#  'retaliating in that way , firstparty asserted , violated section 704(a ) of title vii , which forbids an employer to " discriminate against any of his employees ... because he has ... made a charge ... under this title . "',
#  'the u.s . district court for the eastern district of kentucky dismissed firstparty \'s complaint , holding that title vii " does not permit third party retaliation claims . "',
#  "a splintered en banc court upheld the dismissal of firstparty 's complaint . \n",
#  'secondparty filed a grievance with the california prison system , but it was dismissed because he had waited too long to file it .',
#  'the district court agreed , but the ninth circuit court of appeals reversed , finding that all of secondparty \'s administrative remedies were " exhausted " because they were no longer available to him . \n',
#  'asserting state law claims , secondparty , a kentucky native , brought suit in kentucky state court , for injuries sustained in a construction accident , against firstparty .',
#  '( firstparty ) , a delaware corporation , and whayne supply company ( whayne ) , a kentucky corporation .',
#  'less than a year after filing his complaint secondparty entered into a settlement with whayne .',
#  'firstparty immediately moved to remove the action to federal court , arguing that the settlement between secondparty and whayne meant that there was complete diversity .',
#  'secondparty protested that complete diversity was not present because liberty mutual had not yet settled with whayne , so that both whayne and secondparty were still party to the lawsuit .',
#  "the district court denied secondparty ' motion to remand , erroneously concluding that complete diversity was present .",
#  'complete diversity was present for the remainder of the case , including trial and judgment in favor of firstparty .',
#  "secondparty was arrested for the murder of a ten - year - old girl who 's body he disposed of along a gravel road .",
#  "during the search , after responding to an officer 's appeal for assistance , secondparty made statements to the police ( without an attorney present ) which helped lead the searchers to the child 's body .",
#  'secondparty , corporation counsel for the city of new york , sought such an injunction against several bookstores .',
#  'firstparty was diagnosed with hepatitis c while imprisoned at limon correctional facility in limon , colorado .',
#  'firstparty was accused of stealing the syringe and utilizing it for illegal drug use , after which he was denied further treatment .',
#  'firstparty sued prison medical officials under 42 u.s.c .',
#  'and argued that the refusal of medical treatment violated his eighth amendment rights because he was suffering liver damage and threat of death by not being treated for hepatitis c. the trial court dismissed firstparty ’s suit on the grounds that he could not prove he was suffering substantial harm because he was being denied medical treatment .',
#  'fox west coast firstparty held various contracts for " first - run " rights of movies in san bernardino , ca .',
#  'firstparty theatre opened a drive - in theater in the area and threatened to sue fox west coast over their " first - run " contracts claiming they violated antitrust laws , in particular the sherman antitrust act and the clayton act .',
#  'fox west coast filed an injunction against firstparty taking legal action , and firstparty counterclaimed . \n ',
#  'the lower secondparty denied firstparty a trial by jury because the suit involved both matters of law and equitable damages .',
#  'firstparty appealed this decision on the grounds that the alleged competition between firstparty and fox west coast was a matter of fact to be decided by a jury pursuant to the seventh amendment .',
#  'the ninth circuit secondparty of appeals affirmed the lower secondparty ’s decision .',
#  'firstparty responded by seeking a writ of mandamus . \n',
#  'in 2012 , the firstparty legislature redrew firstparty ’s electoral districts with the goal of creating districts with a population deviation of only 1 % , as opposed to the 5 % courts traditionally allow when evaluating redistricting efforts .',
#  'firstparty also tried to maintain the existing percentage of minority voters in each electoral district .',
#  'petitioners sued in district court and argued that firstparty ’s redistricting violated the voting rights act and amounted to racial gerrymandering that had negative impacts on the equal representation of racial minorities in multiple electoral districts .',
#  'the district court held that the petitioners had failed to prove that firstparty used race as a “ dominant and controlling ” factor in redrawing its electoral districts and also that firstparty ’s goal of maintaining the minority population percentages in existing districts was “ narrowly tailored ” to a compelling state interest .',
#  'firstparty was driving on a divided four - lane highway near harrisburg , pennsylvania , when he was pulled over allegedly for violating a state law requiring drivers to use the left lane for passing only .',
#  'recognizing the car as a rental car , the officers asked firstparty for his license and rental agreement , which he had difficulty locating .',
#  'once he did locate them , the officers noted that the rental agreement did not list firstparty as an authorized driver , and when they ran his identification , they noted that he was using an alias and had an outstanding warrant in new jersey .',
#  'despite the warrant ’s indication that it did not request extradition from other jurisdictions , the officers attempted to contact authorities in new jersey to confirm they did not seek firstparty ’s arrest and extradition , allegedly following protocol for such situations .',
#  'the officers experienced difficulty with their communications , however , and returned to firstparty ’s car , where they asked him to exit the vehicle and about his warrant and alias . \n ',
#  'the officers asked whether firstparty had anything illegal in the car and then requested firstparty ’s consent to search the car , noting that they did not actually need his consent because he was not listed on the rental agreement .',
#  'the officers allege that firstparty gave his consent , but firstparty disputes this contention .',
#  'at trial , firstparty moved to suppress the evidence , challenging the initial stop , the extension of the stop , and the search .',
#  'firstparty maintains that he did not consent to the search , so the issue remains whether he needed to consent at all — that is , whether he had a reasonable expectation of privacy in the rental vehicle , despite not being listed on the rental agreement .',
#  'thus , the district court denied firstparty ’s motion to suppress , and the third circuit , reviewing the factual questions for clear error and the legal question de novo , affirmed the judgment of the district court . \n',
#  'following consolidation of the claims before the u.s . court of appeals for the sixth circuit , the firstparty of firstparty intervened to join the plaintiffs and moved to dismiss .',
#  'a georgia state court convicted johnny secondparty of violating a state statute .',
#  'on appeal , mr . secondparty argued that the statute violated the first and fourteenth amendments .',
#  'mr . secondparty successfully sought habeas corpus relief from a georgia federal district court .',
#  'firstparty is a holding company incorporated in delaware , with a principal place of business in beijing .',
#  'the company represented that it manufactured and sold organic compound fertilizers and other agricultural products to farmers in over two dozen provinces throughout firstparty .',
#  'in 2011 , company shareholders alleged fraudulent business practices by firstparty .',
#  'later that year , nasdaq halted trading in and initiated delisting proceedings against firstparty ’s stock , and in 2012 the sec revoked the stock ’s registration . \n ',
#  'shareholders sued firstparty in two successive putative class actions in 2011 and 2012 , alleging various securities law violations against the company and several individual defendants .',
#  'shareholder secondparty brought a third putative class action against the company and individual defendants in 2014 , alleging securities law violations arising from the same facts and circumstances as the first two cases .',
#  'firstparty moved to dismiss the complaint on the basis that it had been filed after the two year limitations period applicable under the securities exchange act of 1934 .',
#  'secondparty and the additional plaintiffs argued that under the american pipe & construction v. utah line of cases , the limitations period had been tolled on their claims during the pendency of the two prior class actions .',
#  'planned secondparty sued the firstparty of the united states , arguing that the act was unconstitutional under the right to an abortion protected by the substantive component of the due process clause of the fifth amendment , as interpreted by the supreme court in roe v. wade and subsequent cases .',
#  'this made the ban expansive enough to qualify as an unconstitutional " undue burden " on the right to abortion , as defined in planned secondparty v. casey . \n ',
#  'don secondparty , a non - incumbent house of representatives candidate , brought suit to enjoin the secretary from implementing the article .',
#  'secondparty and mary secondparty ’s three - and - a - half year old daughter amber had spina bifida .',
#  'in 1979 , irving independent firstparty agreed to provide special education for amber as required by the federal education of the handicapped act ( eha ) .',
#  'her program , however , made no provision for firstparty personnel to administer cic .',
#  'the tatros unsuccessfully pursued administrative remedies to secure cic services during firstparty hours . \n ',
#  'in october 1979 , the tatros filed an action against the firstparty , the texas state board of education , and others .',
#  'they sought an injunction requiring the firstparty to provide amber with cic .',
#  "the firstparty court denied the tatros ' request for a preliminary injunction , concluding that cic was not a ‘ related service ’ under the eha because it did not arise from an effort to educate .",
#  'the united states court of appeals , fifth circuit reversed , holding that cic was indeed a ‘ related service ’ under the eha , and remanded the case to the firstparty court .',
#  'the firstparty court then ruled that cic was not a ‘ medical service ’ under the eha because a doctor was not needed to administer the procedure .',
#  'interest federally funded interest accrued on iolta accounts is then paid to the texas equal access to justice secondparty ( secondparty ) which supports legal services for low - income persons .',
#  'acting on behalf of others opposed to iolta , the secondparty legal secondparty ( the " secondparty " ) challenged secondparty \'s receipt and use of the iolta funds .',
#  "on appeal from an appellate court 's reversal of a favorable district court decision , the supreme court granted the secondparty certiorari . \n",
#  'a 1994 amendment to the firstparty constitution said criminal defendants who pled guilty had no right to appeal and could appeal only with the permission of a state appellate firstparty .',
#  'firstparty then enacted a law that said in most cases judges could not appoint appellate lawyers for indigent defendants who pled guilty .',
#  'the district firstparty ruled that the indigents had standing to sue and that the lawyers who sued with them had the right to sue as third - party representatives of the rights of indigents .',
#  "a federal appellate firstparty agreed the statute was unconstitutional , but based this only on the lawyers ' claims .",
#  "the firstparty said the u.s . supreme firstparty 's 1971 decision in younger v. harris required it to abstain from hearing the indigents ' claims because the indigents were involved in related proceedings in state firstparty . \n",
#  'firstparty , a mexican national living in south dakota , was convicted of aiding and abetting the possession of cocaine .',
#  'the immigration and naturalization service began proceedings to remove firstparty from the country .',
#  'firstparty applied for a cancellation of his removal , citing the immigration and naturalization act ( ina ) .',
#  'firstparty argued that he was eligible for cancellation of his removal because his drug offense was only a misdemeanor under federal law . \n ',
#  "an immigration judge denied firstparty 's request for cancellation , and the board of immigration appeals affirmed , on the grounds that firstparty had committed an aggravated felony .",
#  'firstparty then sued the secondparty and brought his case to the court of appeals for the eighth circuit .',
#  'firstparty was a salaried employee who worked at brainerd army store , which was owned by his brother , tony firstparty .',
#  'in 2008 , when firstparty noticed an increase in the number of “ edgy looking ” people purchasing polar pure , an iodine - based water purification product , he called the local police station to find out if there was anything he should know about it .',
#  'the police confirmed firstparty ’s suspicion that polar pure was being used to manufacture methamphetamine and that he should n’t sell it if he felt uncomfortable .',
#  'brainerd army store was the only place that sold polar pure locally , and the product was kept behind the counter , so only the firstparty brothers sold it .',
#  'over the course of the next year , the firstparty brothers sold increasing amounts of polar pure .',
#  'tony pled guilty , and firstparty went to trial , where he was convicted on 11 of the 14 counts with which he was charged .',
#  'the jury found him guilty and sentenced him to concurrent terms of 60 months for each count , but the jury did not order any forfeiture of the proceeds of the sales , because it found that , as a salaried employee , firstparty did not reap the proceeds of the conspiracy . \n ',
#  'firstparty and others did not qualify for employment under the alaska residency standard . \n',
#  'five months after his release on parole , he murdered mary ellen firstparty , a fifteen - year - old girl .',
#  'her family , sued the parole official for negligence , but the district court dismissed the case because a secondparty statute states that a parole officer can not be liable for injury resulting from the decision to revoke parole or release a parolee .',
#  'the secondparty supreme court also dismissed the case and the firstparty family appealed by arguing the statute of immunization of parole officials violates the due process clause of the fourteenth amendment . \n',
#  'in february 1974 , 18 - years - olds carol mcclintock and wanda lou holbert were seriously injured when an uninsured motorist hit the vehicle mcclintock was driving in their hometown of montville , secondparty .',
#  'when firstparty , a local attorney , learned of the accident , he visited mcclintock in the hospital and offered to represent her in exchange for a portion of the proceeds collected from her insurer .',
#  'firstparty also approached holbert at her home and obtained her oral assent to representation , which he secretly tape - recorded .',
#  'both women eventually discharged firstparty and filed grievances with the local secondparty association , which in turn filed a formal complaint against firstparty with the secondparty of commissioners on grievances and discipline of the supreme court of secondparty ( secondparty ) .',
#  'the secondparty found that firstparty violated provisions of the secondparty code of professional responsibility that banned a lawyer ’s in - person solicitation of employment to a non - lawyer and publicly reprimanded him .',
#  'on appeal , the supreme court of secondparty rejected firstparty ’s claim that his conduct was protected under the first and fourteenth amendments and increased the sanction against firstparty to indefinite suspension . \n',
#  'during firstparty d. firstparty ’s trial on charges related to a sexual assault of a 4 - year - old girl , secondparty prosecutors twice - attempted to call the child , who was by then five years old , as a witness , but each time she experienced emotional difficulty and left the stand without testifying .',
#  'this testimony was allowed into evidence under secondparty - law hearsay exceptions for spontaneous declarations and statements made in the course of a medical examination .',
#  'on appeal , the secondparty appellate court rejected firstparty ’s claims that the introduction of the out - of - court statements violated his right to confront and cross - examine witnesses under the sixth amendment and affirmed the conviction .',
#  'the secondparty supreme court denied discretionary review of the case . \n',
#  'the internal revenue service ( irs ) contended that elmer and dorothy cullers had established a firstparty for the purpose of evading taxes .',
#  "the irs filed tax liens against the firstparty , freezing the trustees ' assets until the outstanding taxes were paid .",
#  'firstparty of firstparty sued the irs pursuant to 26 u.s.c .',
#  "firstparty claimed in a second suit that the supreme court 's opinion in secondparty v. williams meant that the possibility of a suit under 26 u.s.c .",
#  'firstparty , firstparty .',
#  'the icc granted that authority , and the competing motor carriers sued in u.s . district court for the western district of secondparty to annul the certificate .   ',
#  'secondparty transportation , inc . was a trucking company headquartered in new jersey that in 2006 was purchased by a subsidiary of sun capital partners .',
#  'in 2008 , secondparty filed for bankruptcy under chapter 11 of the bankruptcy code ; at that point , it owed about $ 53 million to its first - priority senior secured creditors and about $ 20 million to its tax and general unsecured creditors .',
#  'two lawsuits ensued in bankruptcy court : one was the truck drivers suing secondparty for violating federal and state worker adjustment and retraining notification acts , which required 60 days ’ notice to workers before they were laid off , and the other was a fraudulent conveyance action on behalf of the unsecured creditors .',
#  "a judge issued a warrant to search secondparty ’ residence based on a federal tax investigator 's affidavit .   ",
#  'the affidavit stated that secondparty had a reputation with the investigator for being a trafficker in illegal liquor , and a local constable located illegal whiskey on secondparty ’ property .   ',
#  'the constable had purchased whiskey from secondparty in the past and feared for his life if his name were revealed .   ',
#  'when police searched secondparty ’ residence , they discovered illegal non - tax paid liquor .   ',
#  'at trial , the district court admitted the evidence obtained during the search , and secondparty was convicted of possession of non - tax paid liquor .   ',
#  'in the midst of a labor strike against southern bell telephone company , louis joseph firstparty , michael louis falcone , and norman mcleod met with james shelby , a union official , in a chicago tavern .',
#  'firstparty and falcone did not go through with the plan and instead informed chicago police when mcleod obtained dynamite and traveled to mississippi .',
#  'firstparty and falcone pled guilty and were sentenced to three months in prison each .',
#  'because several of the targeted facilities were used exclusively by the military and federal agencies , federal prosecutors subsequently charged firstparty , falcone , and shelby with conspiring to destroy property essential to the u.s . communications systems .',
#  'the u.s . court of appeals for the fifth circuit affirmed the judgments against firstparty and falcone on appeal .',
#  'in their petition to the supreme court , firstparty and falcone argued that the federal prosecution subsequent to their convictions under illinois law violated the double jeopardy clause of the fifth amendment , which prevents someone from being tried more than once for the same crime . \n',
#  'between 1995 and 2004 , the firstparty of firstparty ( firstparty ) provided healthcare services to members of the firstparty pursuant to a self - determination contract with the secretary of health and human services ( hhs ) .',
#  'the self - determination contract states that the federal government will pay the participating firstparty the amount that the government would have paid the department of the interior and hhs if those agencies were administering the program .',
#  'the firstparty and the government negotiate those costs in annual funding agreements . \n ',
#  'in 2005 , the firstparty filed administrative claims with the hhs ’s firstparty health service to recover contract support costs for the years 1995 through 2004 .',
#  'the firstparty challenged that decision in federal district court and argued that the statute of limitations should not have been running .',
#  'the district court rejected the firstparty ’s argument .',
#  'the firstparty of firstparty in firstparty , georgia , refused to accept black americans .',
#  'the government sought to enjoin the firstparty from discriminating on the basis of race under title ii . \n',
#  'petitioner firstparty was convicted for federal drug - related offenses in 2005 and sentenced to 120 months ’ imprisonment followed by five years of supervised release .',
#  'while on supervised release , firstparty allegedly engaged in and was indicted for state - law offenses .',
#  'in october 2016 , firstparty pleaded guilty to some of the state - court charges in exchange for a predetermined six - year sentence .',
#  'due to administrative delays and a series of continuances , firstparty was sentenced on march 21 , 2017 .',
#  'on march 30 , 2017 , firstparty ’s probation officer informed the federal district court of firstparty ’s state - court convictions and sentences , and the court exercised jurisdiction to adjudicate whether he violated the terms of his supervised release .',
#  'firstparty challenged the district court ’s exercise of jurisdiction , but the us court of appeals held that under binding precedent , a term of supervised release is paused by imprisonment in connection with a new state conviction .',
#  'in 2016 , citibank initiated a debt - collection action in a north carolina state court against secondparty w. secondparty , alleging that secondparty had failed to pay for a water treatment system he purchased using a citibank - issued credit card .',
#  'in responding to citibank ’s complaint , secondparty asserted a counterclaim against citibank and third - party class - action claims against firstparty and carolina water systems ( cws ) .',
#  'in these third - party claims , secondparty alleged that firstparty and cws had engaged in unfair and deceptive trade practices with respect to the water treatment systems ; secondparty ’s counterclaim against citibank alleged that citibank was jointly and severally liable to him because firstparty had sold or assigned the transaction to citibank .',
#  'citibank subsequently dismissed its claims against secondparty . \n ',
#  'firstparty filed a notice of removal in federal court , citing federal jurisdiction under the class action fairness act ( cafa ) .',
#  'firstparty then filed a motion to realign parties with secondparty as plaintiff and firstparty , cws , and citibank as defendants .',
#  'secondparty moved to remand the case to state court and amended his third - party complaint to remove any reference to citibank . \n ',
#  'the district court denied firstparty ’s motion to realign parties , finding that there were not “ antagonistic parties on the same side , ” and granted secondparty ’s motion to remand because firstparty was not a “ defendant ” eligible to remove under cafa .',
#  'moreover , the fourth circuit found that allowing firstparty to remove would be inconsistent with its prior interpretations of cafa ’s removal statute . \n',
#  'in 81 , firstparty was arrested in his house in 1967 .',
#  'the heroin was admitted at trial and firstparty was convicted of concealing illegally imported heroin .',
#  'firstparty appealed , arguing that the search of his house was illegal under chimel v. california , a case decided on june 23 , 1969 that narrowed the permissible scope of searches incidental to an arrest .',
#  'in november of 1996 , firstparty and several other african americans filed a firstparty action lawsuit in federal district court against r.r . secondparty and secondparty , a commercial printing secondparty .',
#  'secondparty and secondparty , however , argued that the section was bound by a two - year statute of limitations established by illinois for all personal injury claims .',
#  'the suit fell outside that statute of limitations , and the secondparty argued that it should therefore be dismissed . \n ',
#  'firstparty , however , argued that a separate section of u.s.c .',
#  'secondparty and secondparty countered that the 1991 civil rights act had merely amended the section , not created a new law , and that the four - year statute of limitations therefore did not apply . \n ',
#  'a federal district court sided with firstparty .',
# ...
#  'these injuries ultimately left firstparty permanently partially disabled and ended his longshore career .',
#  "in accordance with the longshore and harbor workers ' compensation act , secondparty - secondparty 's insurer paid firstparty compensation for temporary total disability for a period from 2002 to 2005 .",
#  "in may 2005 , the insurer disputed firstparty ' claim and stopped compensating him . \n ",
#  "on october 12 , 2006 , an administrative law judge determined that secondparty - secondparty continued to be liable under the longshore act for firstparty ' on - the - job injuries after may of 2005 .",
#  'the administrative judge determined that the applicable maximum rate for firstparty was $ 966.08 per week , based on fiscal year 2002 , the year firstparty first became disabled .',
#  'firstparty claimed that his maximum rate should be $ 1,114 per week , based on fiscal year 2007 , the year the administrative law judge awarded firstparty compensation . \n ',
#  'firstparty filed a motion for reconsideration , which the administrative judge denied .',
#  'both secondparty - secondparty and firstparty appealed to the benefits review board , which adopted the rationale that the maximum compensation rate was based on the year in which the disability began rather than the year compensation was awarded .',
#  "firstparty appealed to the u.s . court of appeals for the ninth circuit , which affirmed the benefit review board 's interpretation .",
#  'firstparty appealed that decision . \n',
#  'an oregon state police officer suspected secondparty of burglary and asked him to come to the police station for questioning .',
#  'secondparty came freely , spoke with the officer , and was not arrested at the time .',
#  'secondparty moved to suppress the evidence since he was not read his miranda rights before the questioning .',
#  'the court admitted the evidence since secondparty was not in custody during the questioning .',
#  'the firstparty court of appeals affirmed .',
#  'the supreme court of firstparty reversed since it found that matianson was in a " coercive environment " when questioned and therefore deserved to hear his miranda rights . \n',
#  'on january 7 , 1975 , police arrested secondparty in lake county , firstparty .',
#  'secondparty was charged with forgery of a check in the name of bernard isaacs and of possessing stolen credit cards belonging to amy isaacs .',
#  'at the preliminary hearing on january 10 , secondparty ’ lawyer called the isaacs ’ daughter , anita , as a witness to testify that she knew secondparty and allowed him to use her apartment while she was away .',
#  'the attorney attempted to elicit testimony from anita that she gave secondparty the checks and credit cards without telling him that she did not have permission to do so .',
#  'isaacs would not admit to these actions , and secondparty ’ attorney did not ask the court to declare her a hostile witness or place her on cross - examination .',
#  'when ms . isaacs failed to respond to five subpoenas to appear at secondparty ’ subsequent criminal trial , the state entered the transcript of her earlier testimony into evidence , as allowed by an firstparty statute . \n ',
#  'after being convicted by the trial court , secondparty appealed on the grounds that the admission of the prior testimony violated the confrontation clause of the sixth amendment .',
#  'the firstparty court of appeals reversed the conviction and the firstparty supreme court affirmed . \n',
#  'secondparty , a tenured teacher at firstparty , was required to earn five college credits every three years as continuing education .   ',
#  'secondparty refused to comply with this requirement and did not receive a pay increase each year her contract was renewed .   ',
#  'looking for an alternative consequence , the firstparty board warned secondparty that they would not renew her contract the following year if she did not complete her continuing education .   ',
#  'secondparty refused , and the firstparty board voted to terminate her for “ willful neglect of duty ” . \n ',
#  'after unsuccessfully attempting to obtain administrative relief , secondparty sued the firstparty for fourteenth amendment violations .   ',
#  'the firstparty court dismissed the case , but the u.s . court of appeals for the tenth circuit reversed , holding that the termination violated the equal protection and due process clauses of the fourteenth amendment . \n',
#  'a michigan state court convicted secondparty of first - degree murder , assault with intent to commit murder , and several firearms related charges .',
#  'after exhausting his remedies in michigan state court , secondparty petitioned for habeas corpus relief in a michigan federal district court .',
#  'on appeal , secondparty argued that his confession was obtained in violation of the fifth amendment and that he was denied effective counsel at trial .',
#  "the sixth circuit held that the michigan supreme court 's finding that secondparty waived his fifth amendment right was unreasonable because secondparty refused to sign an acknowledgement that he had been informed of his miranda rights and rarely made eye contact with the officer throughout the three hour interview .",
#  "the sixth circuit also held that the michigan supreme court improperly determined that secondparty was not prejudiced by his counsel 's failure to request a limiting instruction related to his separately tried co - defendant 's testimony . \n",
#  'on march 8 , 2013 , police officers executed a warrant to search firstparty ’ house following allegations of sexual abuse from young men .',
#  'after he was arrested and while in custody , firstparty admitted to owning the rifle and ammunition , and he was charged with being a felon in possession of a firearm in violation of the armed career criminal act ( acca ) because of his five previous burglary convictions in iowa state courts .',
#  'at trial , the district court used a modified categorical approach to determine that firstparty ’ prior convictions constituted violent felonies because the elements of the offense were substantially similar to generic burglary and posed the same risk of harm to others .',
#  'therefore , firstparty was sentenced to 180 months imprisonment pursuant to the acca .',
#  "firstparty appealed his conviction and argued that his iowa convictions should not have constituted predicate offenses under the acca , but the u.s . court of appeals for the eighth circuit affirmed the lower court 's decision . \n",
#  'firstparty ( firstparty ) is a wisconsin - based healthcare data management software company .',
#  'firstparty has an arbitration agreement that requires its employees to resolve any employment - based disputes with epic through individual arbitration and to waive their right to participate in or receive benefit from any class , collective , or representative proceedings .',
#  'in february 2015 , former epic employee secondparty sued epic in federal court individually and on behalf of similarly - situated employees and claimed that they had been denied overtime wages in violation of the fair labor standards act of 1938 .',
#  'firstparty moved to dismiss the complaint and cited the waiver clause of its arbitration agreement .',
#  'the district court denied firstparty ’s motion and held that the waiver was unenforceable because it violated the right of employees to engage in “ concerted activities ” under section seven of the national labor relations act ( nlra ) .',
#  'three days after his arrest by local police on state narcotics charges , pedro secondparty - secondparty confessed to the secret service that federal reserve notes found in his home were counterfeit .',
#  'when he was subsequently charged with the federal offense of possession of counterfeit currency , secondparty defended himself by claiming that the delay between his arrest on state charges and his presentment on the federal charge rendered his confession inadmissible .',
#  'secondparty cited 18 u.s.c .',
#  "on appeal from a reversal of a district court 's decision to uphold the confession , the supreme court granted the firstparty certiorari . \n",
#  'secondparty used a " worldwide combined reporting " method to determine secondparty liability for multinational corporations operating inside the state .',
#  'barclays firstparty of secondparty ( secondparty ) was wholly owned by a multinational corporation , barclays firstparty international limited ( bbi ) .',
#  'secondparty did not include financial data for bbi in its 1977 secondparty filings .',
#  'the secondparty board ( secondparty board ) determined that secondparty misrepresented the proportion of income subject to taxation , causing a secondparty deficiency of over one hundred thousand dollars .',
#  "barcal and bbi paid , but then sued for the amount paid , complaining that the cost to provide bbi 's worldwide financial data was disproportionately large considering that secondparty operated largely independently of bbi and bbi operated largely outside of secondparty .",
#  'secondparty and bbi contended that this violated the commerce clause - derived anti - discrimination requirement , which prevents states from imposing disproportionately large secondparty compliance burdens upon corporations .',
#  'the secondparty board allowed bbi to make a " reasonable approximation " of financial data to minimize costs , but bbi claimed that this action violated due process by admitting financial data that was possibly inaccurate . \n ',
#  'the secondparty supreme court found no constitutional violation and remanded the case to a secondparty court of appeals , which also did not find the burden disproportionate .',
#  '( the case was consolidated with colgate palmolive co. v. secondparty board of secondparty . ) \n',
#  'jeffrey secondparty is a paraplegic .',
#  'secondparty was removed from his wheelchair and seatbelted to a bench in the van .',
#  'during the ride , secondparty fell to the floor , suffering serious injuries that left him unable to work full time .',
#  'secondparty sued certain kansas police officials for discriminating against him on the basis of his disability , in violation of the americans with disabilities act of 1990 ( ada ) and the rehabilitation act of 1973 , by failing to maintain appropriate policies for the arrest and transportation of persons with spinal cord injuries .',
#  'in firstparty v. secondparty 95 - 1691 , the police observed secondparty participating in a number of drug transactions out of his car on a street in philadelphia .',
#  "without a warrant , but with probable cause , the police then found cocaine when they searched the trunk of secondparty 's car .",
#  "ultimately , the firstparty supreme court held the search unconstitutional , finding that the automobile exception to the fourth amendment 's warrant requirement required both the existence of probable cause and the presence of exigent circumstances to justify a warrantless search .",
#  "in firstparty v. kilgore 95 - 1738 , a search of randy kilgore 's truck during a drug raid on his home turned up cocaine .",
#  'again the firstparty supreme court suppressed the evidence seized , holding that fourth amendment requires police to obtain a warrant before searching an automobile unless exigent circumstances are present . \n',
#  'for over a century after the alaska purchase in 1867 , the federal government had no settled policy on recognition of alaska native groups as indian secondparty .',
#  'in 1975 , congress enacted the indian self - determination and education assistance act ( isda ) to “ help indian secondparty assume responsibility for aid programs that benefit their members . ”',
#  'the department of the firstparty concluded that ancs were eligible to receive title v funds . \n ',
#  'six federally recognized secondparty in alaska and twelve federally recognized secondparty in the lower 48 states challenged that determination , arguing that ancs are not “ indian secondparty ” within the meaning of the cares act or isda .',
#  'the district court granted summary judgment to the defendants , finding that ancs must qualify as indian secondparty to give effect to their express inclusion in the isda definition , even though no anc has been recognized as an indian tribe .',
#  'the u.s . court of appeals for the district of columbia reversed , holding that ancs are not eligible for funding under title v of the cares act because they are not “ recognized ” as indian secondparty . \n',
#  'until about 1920 , the secondparty mattress company was the sole manufacturer of secondparty products at its four factories in the midwest and southwest .',
#  'by 1923 , however , some 19 independent factories operated under secondparty licenses .',
#  'soon thereafter , these licensees and new owner e. e. edwards formed the secondparty corporation .',
#  'secondparty continued to license the use of the secondparty mark to independent stock - holding bedding manufacturers . \n ',
#  'in 1925 , the licensees agreed on a system of allocating exclusive territories to market secondparty products .',
#  'around this time , the licensee - stockholders and secondparty began collaborating to fix and police the minimum and maximum prices charged by retailers of secondparty products , the advertised prices of secondparty products , and the means of inducing retailers to adhere to these prices .',
#  'in 1933 , secondparty corporation reorganized into secondparty , incorporated .',
#  'secondparty , secondparty .',
#  'made a new provision that any new manufacturers coming into the organization must purchase secondparty stock .',
#  'in the 1940 ’s , secondparty ’s business increased and many new licensees joined to cover previously open territories . \n ',
#  'the firstparty brought a civil action against secondparty , secondparty .',
#  'it also alleged that secondparty , secondparty .',
#  'the district court held that secondparty , secondparty .',
#  'the firstparty appealed the district court ’s ruling on the legality of secondparty , secondparty .',
#  'firstparty was a witness at a federal grand jury investigation into possible violations of the federal motor carrier act ( fmca ) .   ',
#  'firstparty refused to answer questions asked by the grand jury , invoking the fifth amendment protection against self - incrimination .   ',
#  'the district judge ordered firstparty to answer the questions , telling him that the fmca provided immunity against any prosecution that might arise from firstparty ’s testimony .   ',
#  'firstparty still refused to answer .   ',
#  'janet secondparty - secondparty filed suit under 42 u.s.c .',
#  "section 1983 against the city of fall river , massachusetts , the city 's mayor , daniel firstparty , the vice president of the city counsel , marilyn roderick , and others , alleging that the elimination of the city department in which secondparty - secondparty was the sole employee was motivated by a desire to retaliate against her for exercising her first amendment rights .",
#  'the jury found the city , firstparty and roderick liable on the first amendment claim .',
#  'the first circuit set aside the verdict against the city , but affirmed the judgments against firstparty and roderick .',
#  "the court held that although firstparty and roderick had absolute immunity from civil liability for their performance of legitimate legislative activities , their conduct in voting for and signing the ordinance that eliminated secondparty - secondparty 's office was motivated by considerations relating to a particular individual and was therefore administrative rather than legislative in nature . \n",
#  'a california trial firstparty convicted attorney secondparty of summary contempt for her conduct in court .',
#  'after the firstparty had stated repeatedly not to discuss punishment , secondparty asked her client whether he was facing the death penalty and whether he was facing life without possibility of parole .',
#  ...]

# %%
woi_df = pd.DataFrame(sentences_with_words, columns=['sentences'])
woi_verb_list = []
# woi_verb_info_list = []

for fact in woi_df['sentences']:
    doc = nlp(fact.lower())
    for token in doc:
        if token.pos_ == 'VERB':
            woi_verb_list.append(token.lemma_)
            # verb_info = {'lemma': token.lemma_, 'dependency': token.dep_}  # Save as a dictionary
            # woi_verb_info_list.append(verb_info)

# %%
stat_woi_verb_list = Counter(woi_verb_list).most_common()
stat_woi_verb_list[:25]
# Out:
# [('file', 896),
#  ('hold', 822),
#  ('argue', 740),
#  ('violate', 653),
#  ('find', 627),
#  ('sue', 528),
#  ('deny', 522),
#  ('allege', 469),
#  ('have', 456),
#  ('convict', 436),
#  ('affirm', 434),
#  ('appeal', 418),
#  ('claim', 395),
#  ('grant', 393),
#  ('seek', 361),
#  ('require', 356),
#  ('rule', 343),
#  ('dismiss', 331),
#  ('reverse', 319),
#  ('make', 293),
#  ('use', 286),
#  ('base', 262),
#  ('provide', 251),
#  ('apply', 245),
#  ('fail', 240)]

# %% [markdown]
# ## New Party Encoding

# %%
print(train_df['facts'][0])
print(train_df['new_facts'][0])
# Out:
# on june 27, 1962, phil st. amant, a candidate for public office, made a television speech in baton rouge, louisiana.  during this speech, st. amant accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union.  finally, st. amant implicated herman thompson, an east baton rouge deputy sheriff, in a scheme to move money between the teamsters union and st. amant’s political opponent.
# thompson successfully sued st. amant for defamation.  louisiana’s first circuit court of appeals reversed, holding that thompson did not show st. amant acted with “malice.”  thompson then appealed to the supreme court of louisiana.  that court held that, although public figures forfeit some of their first amendment protection from defamation, st. amant accused thompson of a crime with utter disregard of whether the remarks were true.  finally, that court held that the first amendment protects uninhibited, robust debate, rather than an open season to shoot down the good name of anyone who happens to be a public servant.
#
# on june 27 , 1962 , firstparty . firstparty , a candidate for public office , made a television speech in baton rouge , louisiana .   during this speech , firstparty . firstparty accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union .   finally , firstparty . firstparty implicated secondparty , an east baton rouge deputy sheriff , in a scheme to move money between the teamsters union and firstparty . firstparty ’s political opponent .
#  secondparty successfully sued firstparty . firstparty for defamation .   louisiana ’s first circuit court of appeals reversed , holding that secondparty did not show firstparty . firstparty acted with “ malice . ”   secondparty then appealed to the supreme court of louisiana .   that court held that , although public figures forfeit some of their first amendment protection from defamation , firstparty . firstparty accused secondparty of a crime with utter disregard of whether the remarks were true .   finally , that court held that the first amendment protects uninhibited , robust debate , rather than an open season to shoot down the good name of anyone who happens to be a public servant .

# %%
train_df['facts'][0]
# Out:
# 'on june 27, 1962, phil st. amant, a candidate for public office, made a television speech in baton rouge, louisiana.  during this speech, st. amant accused his political opponent of being a communist and of being involved in criminal activities with the head of the local teamsters union.  finally, st. amant implicated herman thompson, an east baton rouge deputy sheriff, in a scheme to move money between the teamsters union and st. amant’s political opponent. \nthompson successfully sued st. amant for defamation.  louisiana’s first circuit court of appeals reversed, holding that thompson did not show st. amant acted with “malice.”  thompson then appealed to the supreme court of louisiana.  that court held that, although public figures forfeit some of their first amendment protection from defamation, st. amant accused thompson of a crime with utter disregard of whether the remarks were true.  finally, that court held that the first amendment protects uninhibited, robust debate, rather than an open season to shoot down the good name of anyone who happens to be a public servant. \n'

# %%
idx = 0
first_party = train_df.loc[idx, 'first_party'].lower()
second_party = train_df.loc[idx, 'second_party'].lower()
fact = train_df.loc[idx, 'facts'].lower()

nlp = spacy.load('en_core_web_sm')
doc = nlp(fact)

sen_table = prettytable.PrettyTable()
sen_table.field_names = ['Token', 'Lemma', 'POS', 'Tag', 'Dep', "HEAD"]

for token in doc:
    sen_table.add_row([token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.head.text])

print(sen_table)
# Out:
# +--------------+--------------+-------+------+----------+------------+
# |    Token     |    Lemma     |  POS  | Tag  |   Dep    |    HEAD    |
# +--------------+--------------+-------+------+----------+------------+
# |      on      |      on      |  ADP  |  IN  |   prep   |    made    |
# |     june     |     june     | PROPN | NNP  |   pobj   |     on     |
# |      27      |      27      |  NUM  |  CD  |  nummod  |    june    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |    june    |
# |     1962     |     1962     |  NUM  |  CD  |  nummod  |    june    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |    made    |
# |     phil     |     phil     | PROPN | NNP  | compound |     st     |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   |    made    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   amant    |
# |      a       |      a       |  DET  |  DT  |   det    | candidate  |
# |  candidate   |  candidate   |  NOUN |  NN  |  appos   |   amant    |
# |     for      |     for      |  ADP  |  IN  |   prep   | candidate  |
# |    public    |    public    |  ADJ  |  JJ  |   amod   |   office   |
# |    office    |    office    |  NOUN |  NN  |   pobj   |    for     |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   amant    |
# |     made     |     make     |  VERB | VBD  |   ROOT   |    made    |
# |      a       |      a       |  DET  |  DT  |   det    |   speech   |
# |  television  |  television  |  NOUN |  NN  | compound |   speech   |
# |    speech    |    speech    |  NOUN |  NN  |   dobj   |    made    |
# |      in      |      in      |  ADP  |  IN  |   prep   |   speech   |
# |    baton     |    baton     | PROPN | NNP  | compound |   rouge    |
# |    rouge     |    rouge     | PROPN | NNP  |   pobj   |     in     |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   rouge    |
# |  louisiana   |  louisiana   | PROPN | NNP  |  appos   |   rouge    |
# |      .       |      .       | PUNCT |  .   |  punct   |    made    |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |    during    |    during    |  ADP  |  IN  |   prep   |  accused   |
# |     this     |     this     |  DET  |  DT  |   det    |   speech   |
# |    speech    |    speech    |  NOUN |  NN  |   pobj   |   during   |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  accused   |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   |  accused   |
# |   accused    |    accuse    |  VERB | VBD  |   ROOT   |  accused   |
# |     his      |     his      |  PRON | PRP$ |   poss   |  opponent  |
# |  political   |  political   |  ADJ  |  JJ  |   amod   |  opponent  |
# |   opponent   |   opponent   |  NOUN |  NN  |   dobj   |  accused   |
# |      of      |      of      |  ADP  |  IN  |   prep   |  opponent  |
# |    being     |      be      |  AUX  | VBG  |  pcomp   |     of     |
# |      a       |      a       |  DET  |  DT  |   det    | communist  |
# |  communist   |  communist   |  NOUN |  NN  |   attr   |   being    |
# |     and      |     and      | CCONJ |  CC  |    cc    |     of     |
# |      of      |      of      |  ADP  |  IN  |   conj   |     of     |
# |    being     |      be      |  AUX  | VBG  | auxpass  |  involved  |
# |   involved   |   involve    |  VERB | VBN  |  pcomp   |     of     |
# |      in      |      in      |  ADP  |  IN  |   prep   |  involved  |
# |   criminal   |   criminal   |  ADJ  |  JJ  |   amod   | activities |
# |  activities  |   activity   |  NOUN | NNS  |   pobj   |     in     |
# |     with     |     with     |  ADP  |  IN  |   prep   |  involved  |
# |     the      |     the      |  DET  |  DT  |   det    |    head    |
# |     head     |     head     |  NOUN |  NN  |   pobj   |    with    |
# |      of      |      of      |  ADP  |  IN  |   prep   |    head    |
# |     the      |     the      |  DET  |  DT  |   det    |   union    |
# |    local     |    local     |  ADJ  |  JJ  |   amod   |   union    |
# |  teamsters   |   teamster   |  NOUN | NNS  | compound |   union    |
# |    union     |    union     |  NOUN |  NN  |   pobj   |     of     |
# |      .       |      .       | PUNCT |  .   |  punct   |  accused   |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |   finally    |   finally    |  ADV  |  RB  |  advmod  | implicated |
# |      ,       |      ,       | PUNCT |  ,   |  punct   | implicated |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   | implicated |
# |  implicated  |  implicate   |  VERB | VBD  |   ROOT   | implicated |
# |    herman    |    herman    | PROPN | NNP  | compound |  thompson  |
# |   thompson   |   thompson   | PROPN | NNP  |   dobj   | implicated |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  thompson  |
# |      an      |      an      |  DET  |  DT  |   det    |  sheriff   |
# |     east     |     east     | PROPN | NNP  | compound |   baton    |
# |    baton     |    baton     | PROPN | NNP  | compound |  sheriff   |
# |    rouge     |    rouge     | PROPN | NNP  | compound |  sheriff   |
# |    deputy    |    deputy    | PROPN | NNP  | compound |  sheriff   |
# |   sheriff    |   sheriff    |  NOUN |  NN  |  appos   |  thompson  |
# |      ,       |      ,       | PUNCT |  ,   |  punct   | implicated |
# |      in      |      in      |  ADP  |  IN  |   prep   | implicated |
# |      a       |      a       |  DET  |  DT  |   det    |   scheme   |
# |    scheme    |    scheme    |  NOUN |  NN  |   pobj   |     in     |
# |      to      |      to      |  PART |  TO  |   aux    |    move    |
# |     move     |     move     |  VERB |  VB  |   acl    |   scheme   |
# |    money     |    money     |  NOUN |  NN  |   dobj   |    move    |
# |   between    |   between    |  ADP  |  IN  |   prep   |    move    |
# |     the      |     the      |  DET  |  DT  |   det    |   union    |
# |  teamsters   |   teamster   |  NOUN | NNS  | compound |   union    |
# |    union     |    union     | PROPN | NNP  |   pobj   |  between   |
# |     and      |     and      | CCONJ |  CC  |    cc    |   union    |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |   poss   |  opponent  |
# |      ’s      |      ’s      |  PART | POS  |   case   |   amant    |
# |  political   |  political   |  ADJ  |  JJ  |   amod   |  opponent  |
# |   opponent   |   opponent   |  NOUN |  NN  |   conj   |   union    |
# |      .       |      .       | PUNCT |  .   |  punct   | implicated |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |              |              |       |      |          |            |
# |   thompson   |   thompson   | PROPN | NNP  |  nsubj   |    sued    |
# | successfully | successfully |  ADV  |  RB  |  advmod  |    sued    |
# |     sued     |     sue      |  VERB | VBD  |   ROOT   |    sued    |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |   dobj   |    sued    |
# |     for      |     for      |  ADP  |  IN  |   prep   |   amant    |
# |  defamation  |  defamation  |  NOUN |  NN  |   pobj   |    for     |
# |      .       |      .       | PUNCT |  .   |  punct   |    sued    |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |  louisiana   |  louisiana   | PROPN | NNP  |   poss   |   court    |
# |      ’s      |      ’s      |  PART | POS  |   case   | louisiana  |
# |    first     |    first     |  ADJ  |  JJ  |   amod   |   court    |
# |   circuit    |   circuit    | PROPN | NNP  | compound |   court    |
# |    court     |    court     | PROPN | NNP  |  nsubj   |  reversed  |
# |      of      |      of      |  ADP  |  IN  |   prep   |   court    |
# |   appeals    |    appeal    |  NOUN | NNS  |   pobj   |     of     |
# |   reversed   |   reverse    |  VERB | VBD  |   ROOT   |  reversed  |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  reversed  |
# |   holding    |     hold     |  VERB | VBG  |  csubj   |    show    |
# |     that     |     that     |  DET  |  DT  |   det    |  thompson  |
# |   thompson   |   thompson   |  NOUN |  NN  |   dobj   |  holding   |
# |     did      |      do      |  AUX  | VBD  |   aux    |    show    |
# |     not      |     not      |  PART |  RB  |   neg    |    show    |
# |     show     |     show     |  VERB |  VB  |  ccomp   |  reversed  |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   |   acted    |
# |    acted     |     act      |  VERB | VBD  |  ccomp   |    show    |
# |     with     |     with     |  ADP  |  IN  |   prep   |   acted    |
# |      “       |      "       | PUNCT |  ``  |  punct   |    with    |
# |    malice    |    malice    |  NOUN |  NN  |   pobj   |    with    |
# |      .       |      .       | PUNCT |  .   |  punct   |  reversed  |
# |      ”       |      "       | PUNCT |  ''  |  punct   |  reversed  |
# |              |              | SPACE | _SP  |   dep    |     ”      |
# |   thompson   |   thompson   | PROPN | NNP  |  nsubj   |  appealed  |
# |     then     |     then     |  ADV  |  RB  |  advmod  |  appealed  |
# |   appealed   |    appeal    |  VERB | VBD  |   ROOT   |  appealed  |
# |      to      |      to      |  ADP  |  IN  |   prep   |  appealed  |
# |     the      |     the      |  DET  |  DT  |   det    |   court    |
# |   supreme    |   supreme    | PROPN | NNP  | compound |   court    |
# |    court     |    court     | PROPN | NNP  |   pobj   |     to     |
# |      of      |      of      |  ADP  |  IN  |   prep   |   court    |
# |  louisiana   |  louisiana   | PROPN | NNP  |   pobj   |     of     |
# |      .       |      .       | PUNCT |  .   |  punct   |  appealed  |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |     that     |     that     |  DET  |  DT  |   det    |   court    |
# |    court     |    court     |  NOUN |  NN  |  nsubj   |    held    |
# |     held     |     hold     |  VERB | VBD  |   ROOT   |    held    |
# |     that     |     that     | SCONJ |  IN  |   mark   |  accused   |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  accused   |
# |   although   |   although   | SCONJ |  IN  |   mark   |  forfeit   |
# |    public    |    public    |  ADJ  |  JJ  |   amod   |  figures   |
# |   figures    |    figure    |  NOUN | NNS  |  nsubj   |  forfeit   |
# |   forfeit    |   forfeit    |  ADP  |  IN  |  advcl   |  accused   |
# |     some     |     some     |  PRON |  DT  |   dobj   |  forfeit   |
# |      of      |      of      |  ADP  |  IN  |   prep   |    some    |
# |    their     |    their     |  PRON | PRP$ |   poss   | protection |
# |    first     |    first     |  ADJ  |  JJ  |   amod   | protection |
# |  amendment   |  amendment   |  NOUN |  NN  | compound | protection |
# |  protection  |  protection  |  NOUN |  NN  |   pobj   |     of     |
# |     from     |     from     |  ADP  |  IN  |   prep   | protection |
# |  defamation  |  defamation  |  NOUN |  NN  |   pobj   |    from    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |  accused   |
# |      st      |      st      | PROPN | NNP  | compound |   amant    |
# |      .       |      .       | PROPN | NNP  | compound |   amant    |
# |    amant     |    amant     | PROPN | NNP  |  nsubj   |  accused   |
# |   accused    |    accuse    |  VERB | VBD  |  ccomp   |    held    |
# |   thompson   |   thompson   |  NOUN |  NN  |   dobj   |  accused   |
# |      of      |      of      |  ADP  |  IN  |   prep   |  accused   |
# |      a       |      a       |  DET  |  DT  |   det    |   crime    |
# |    crime     |    crime     |  NOUN |  NN  |   pobj   |     of     |
# |     with     |     with     |  ADP  |  IN  |   prep   |   crime    |
# |    utter     |    utter     |  ADJ  |  JJ  |   amod   | disregard  |
# |  disregard   |  disregard   |  NOUN |  NN  |   pobj   |    with    |
# |      of      |      of      |  ADP  |  IN  |   prep   | disregard  |
# |   whether    |   whether    | SCONJ |  IN  |   mark   |    were    |
# |     the      |     the      |  DET  |  DT  |   det    |  remarks   |
# |   remarks    |    remark    |  NOUN | NNS  |  nsubj   |    were    |
# |     were     |      be      |  AUX  | VBD  |  pcomp   |     of     |
# |     true     |     true     |  ADJ  |  JJ  |  acomp   |    were    |
# |      .       |      .       | PUNCT |  .   |  punct   |    held    |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |   finally    |   finally    |  ADV  |  RB  |  advmod  |    held    |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |    held    |
# |     that     |     that     |  DET  |  DT  |   det    |   court    |
# |    court     |    court     |  NOUN |  NN  |  nsubj   |    held    |
# |     held     |     hold     |  VERB | VBD  |   ROOT   |    held    |
# |     that     |     that     | SCONJ |  IN  |   mark   |  protects  |
# |     the      |     the      |  DET  |  DT  |   det    | amendment  |
# |    first     |    first     |  ADJ  |  JJ  |   amod   | amendment  |
# |  amendment   |  amendment   |  NOUN |  NN  |  nsubj   |  protects  |
# |   protects   |   protect    |  VERB | VBZ  |  ccomp   |    held    |
# | uninhibited  | uninhibited  |  ADJ  |  JJ  |   amod   |   debate   |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   debate   |
# |    robust    |    robust    |  ADJ  |  JJ  |   amod   |   debate   |
# |    debate    |    debate    |  NOUN |  NN  |   dobj   |  protects  |
# |      ,       |      ,       | PUNCT |  ,   |  punct   |   debate   |
# |    rather    |    rather    |  ADV  |  RB  |  advmod  |    than    |
# |     than     |     than     |  ADP  |  IN  |    cc    |   debate   |
# |      an      |      an      |  DET  |  DT  |   det    |   season   |
# |     open     |     open     |  ADJ  |  JJ  |   amod   |   season   |
# |    season    |    season    |  NOUN |  NN  |   conj   |   debate   |
# |      to      |      to      |  PART |  TO  |   aux    |   shoot    |
# |    shoot     |    shoot     |  VERB |  VB  |  relcl   |   season   |
# |     down     |     down     |  ADP  |  RP  |   prt    |   shoot    |
# |     the      |     the      |  DET  |  DT  |   det    |    name    |
# |     good     |     good     |  ADJ  |  JJ  |   amod   |    name    |
# |     name     |     name     |  NOUN |  NN  |   dobj   |   shoot    |
# |      of      |      of      |  ADP  |  IN  |   prep   |    name    |
# |    anyone    |    anyone    |  PRON |  NN  |   pobj   |     of     |
# |     who      |     who      |  PRON |  WP  |  nsubj   |  happens   |
# |   happens    |    happen    |  VERB | VBZ  |  relcl   |   anyone   |
# |      to      |      to      |  PART |  TO  |   aux    |     be     |
# |      be      |      be      |  AUX  |  VB  |  xcomp   |  happens   |
# |      a       |      a       |  DET  |  DT  |   det    |  servant   |
# |    public    |    public    |  ADJ  |  JJ  |   amod   |  servant   |
# |   servant    |   servant    |  NOUN |  NN  |   attr   |     be     |
# |      .       |      .       | PUNCT |  .   |  punct   |    held    |
# |              |              | SPACE | _SP  |   dep    |     .      |
# |              |              |       |      |          |            |
# +--------------+--------------+-------+------+----------+------------+
